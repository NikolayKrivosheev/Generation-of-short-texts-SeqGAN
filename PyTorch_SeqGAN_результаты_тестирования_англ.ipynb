# %% [markdown]
# **Предисловие:**
#
# **Реализация основана на работе:** ...
#
# **Результаты данной работы представлены в статье (при использовании просьба ссылаться на следующую работу):** ...
#
# **Выборки данных:**
# >*    Подписи к изображениям на английском языке из выборки COCO Image Captions
# *    Стихи на русском языке с сайта stihi.ru
#
# **Описание работы:**
# > В данной работе проведены реализация, обучение и тестирование нейронных сетей для генерации случайных коротких текстов. Используются такие нейронные сети как LSTM и SeqGAN. Проведена оценка качества генерации текста на основе метрики BLEU. Для обучения и тестирования используются следующие выборки данных:
# *   Подписи к изображениям на английском языке из выборки COCO Image Captions
# *   Стихи на русском языке с сайта stihi.ru

# %% [markdown]
# Список всех установленных библиотек и их версии

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# absl-py                       0.10.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.1.0
# argon2-cffi                   20.1.0
# asgiref                       3.3.1
# astor                         0.8.1
# astropy                       4.1
# astunparse                    1.6.3
# async-generator               1.10
# atari-py                      0.2.6
# atomicwrites                  1.4.0
# attrs                         20.3.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.9.0
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        3.2.1
# blis                          0.4.1
# bokeh                         2.1.1
# Bottleneck                    1.3.2
# branca                        0.4.1
# bs4                           0.0.1
# CacheControl                  0.12.6
# cachetools                    4.1.1
# catalogue                     1.0.0
# certifi                       2020.11.8
# cffi                          1.14.3
# chainer                       7.4.0
# chardet                       3.0.4
# click                         7.1.2
# cloudpickle                   1.3.0
# cmake                         3.12.0
# cmdstanpy                     0.9.5
# colorlover                    0.3.0
# community                     1.0.0b1
# contextlib2                   0.5.5
# convertdate                   2.3.0
# coverage                      3.7.1
# coveralls                     0.5
# crcmod                        1.7
# cufflinks                     0.17.3
# cupy-cuda101                  7.4.0
# cvxopt                        1.2.5
# cvxpy                         1.0.31
# cycler                        0.10.0
# cymem                         2.0.4
# Cython                        0.29.21
# daft                          0.0.4
# dask                          2.12.0
# dataclasses                   0.8
# datascience                   0.10.6
# debugpy                       1.0.0
# decorator                     4.4.2
# defusedxml                    0.6.0
# descartes                     1.1.0
# dill                          0.3.3
# distributed                   1.25.3
# Django                        3.1.3
# dlib                          19.18.0
# dm-tree                       0.1.5
# docopt                        0.6.2
# docutils                      0.16
# dopamine-rl                   1.0.5
# earthengine-api               0.1.238
# easydict                      1.9
# ecos                          2.0.7.post1
# editdistance                  0.5.3
# en-core-web-sm                2.2.5
# entrypoints                   0.3
# ephem                         3.7.7.1
# et-xmlfile                    1.0.1
# fa2                           0.3.5
# fancyimpute                   0.4.3
# fastai                        1.0.61
# fastdtw                       0.3.4
# fastprogress                  1.0.0
# fastrlock                     0.5
# fbprophet                     0.7.1
# feather-format                0.4.1
# filelock                      3.0.12
# firebase-admin                4.4.0
# fix-yahoo-finance             0.0.22
# Flask                         1.1.2
# flatbuffers                   1.12
# folium                        0.8.3
# future                        0.16.0
# gast                          0.3.3
# GDAL                          2.2.2
# gdown                         3.6.4
# gensim                        3.6.0
# geographiclib                 1.50
# geopy                         1.17.0
# gin-config                    0.3.0
# glob2                         0.7
# google                        2.0.3
# google-api-core               1.16.0
# google-api-python-client      1.7.12
# google-auth                   1.17.2
# google-auth-httplib2          0.0.4
# google-auth-oauthlib          0.4.2
# google-cloud-bigquery         1.21.0
# google-cloud-bigquery-storage 1.1.0
# google-cloud-core             1.0.3
# google-cloud-datastore        1.8.0
# google-cloud-firestore        1.7.0
# google-cloud-language         1.2.0
# google-cloud-storage          1.18.1
# google-cloud-translate        1.5.0
# google-colab                  1.0.0
# google-pasta                  0.2.0
# google-resumable-media        0.4.1
# googleapis-common-protos      1.52.0
# googledrivedownloader         0.4
# graphviz                      0.10.1
# grpcio                        1.33.2
# gspread                       3.0.1
# gspread-dataframe             3.0.8
# gym                           0.17.3
# h5py                          2.10.0
# HeapDict                      1.0.1
# holidays                      0.10.3
# holoviews                     1.13.5
# html5lib                      1.0.1
# httpimport                    0.5.18
# httplib2                      0.17.4
# httplib2shim                  0.0.3
# humanize                      0.5.1
# hyperopt                      0.1.2
# ideep4py                      2.0.0.post3
# idna                          2.10
# image                         1.5.33
# imageio                       2.4.1
# imagesize                     1.2.0
# imbalanced-learn              0.4.3
# imblearn                      0.0
# imgaug                        0.2.9
# importlib-metadata            2.0.0
# importlib-resources           3.3.0
# imutils                       0.5.3
# inflect                       2.1.0
# iniconfig                     1.1.1
# intel-openmp                  2020.0.133
# intervaltree                  2.1.0
# ipykernel                     4.10.1
# ipython                       5.5.0
# ipython-genutils              0.2.0
# ipython-sql                   0.3.9
# ipywidgets                    7.5.1
# itsdangerous                  1.1.0
# jax                           0.2.6
# jaxlib                        0.1.57+cuda101
# jdcal                         1.4.1
# jedi                          0.17.2
# jieba                         0.42.1
# Jinja2                        2.11.2
# joblib                        0.17.0
# jpeg4py                       0.1.4
# jsonschema                    2.6.0
# jupyter                       1.0.0
# jupyter-client                5.3.5
# jupyter-console               5.2.0
# jupyter-core                  4.7.0
# jupyterlab-pygments           0.1.2
# kaggle                        1.5.9
# kapre                         0.1.3.1
# Keras                         2.4.3
# Keras-Preprocessing           1.1.2
# keras-vis                     0.4.1
# kiwisolver                    1.3.1
# knnimpute                     0.1.0
# korean-lunar-calendar         0.2.1
# librosa                       0.6.3
# lightgbm                      2.2.3
# llvmlite                      0.31.0
# lmdb                          0.99
# lucid                         0.3.8
# LunarCalendar                 0.0.9
# lxml                          4.2.6
# Markdown                      3.3.3
# MarkupSafe                    1.1.1
# matplotlib                    3.2.2
# matplotlib-venn               0.11.6
# missingno                     0.4.2
# mistune                       0.8.4
# mizani                        0.6.0
# mkl                           2019.0
# mlxtend                       0.14.0
# more-itertools                8.6.0
# moviepy                       0.2.3.5
# mpmath                        1.1.0
# msgpack                       1.0.0
# multiprocess                  0.70.11.1
# multitasking                  0.0.9
# murmurhash                    1.0.4
# music21                       5.5.0
# natsort                       5.5.0
# nbclient                      0.5.1
# nbconvert                     5.6.1
# nbformat                      5.0.8
# nest-asyncio                  1.4.3
# networkx                      2.5
# nibabel                       3.0.2
# nltk                          3.2.5
# notebook                      5.3.1
# np-utils                      0.5.12.1
# numba                         0.48.0
# numexpr                       2.7.1
# numpy                         1.18.5
# nvidia-ml-py3                 7.352.0
# oauth2client                  4.1.3
# oauthlib                      3.1.0
# okgrade                       0.4.3
# opencv-contrib-python         4.1.2.30
# opencv-python                 4.1.2.30
# openpyxl                      2.5.9
# opt-einsum                    3.3.0
# osqp                          0.6.1
# packaging                     20.4
# palettable                    3.3.0
# pandas                        1.1.4
# pandas-datareader             0.9.0
# pandas-gbq                    0.13.3
# pandas-profiling              1.4.1
# pandocfilters                 1.4.3
# panel                         0.9.7
# param                         1.10.0
# parso                         0.7.1
# pathlib                       1.0.1
# patsy                         0.5.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        7.0.0
# pip                           19.3.1
# pip-tools                     4.5.1
# plac                          1.1.3
# plotly                        4.4.1
# plotnine                      0.6.0
# pluggy                        0.7.1
# portpicker                    1.3.1
# prefetch-generator            1.0.1
# preshed                       3.0.4
# prettytable                   2.0.0
# progressbar2                  3.38.0
# prometheus-client             0.9.0
# promise                       2.3
# prompt-toolkit                1.0.18
# protobuf                      3.12.4
# psutil                        5.4.8
# psycopg2                      2.7.6.1
# ptyprocess                    0.6.0
# py                            1.9.0
# pyarrow                       0.14.1
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.2
# pycparser                     2.20
# pyct                          0.4.8
# pydata-google-auth            1.1.0
# pydot                         1.3.0
# pydot-ng                      2.0.0
# pydotplus                     2.0.2
# PyDrive                       1.3.1
# pyemd                         0.5.1
# pyglet                        1.5.0
# Pygments                      2.6.1
# pygobject                     3.26.1
# pymc3                         3.7
# PyMeeus                       0.3.7
# pymongo                       3.11.1
# pymystem3                     0.2.0
# PyOpenGL                      3.1.5
# pyparsing                     2.4.7
# pyrsistent                    0.17.3
# pysndfile                     1.3.8
# PySocks                       1.7.1
# pystan                        2.19.1.1
# pytest                        3.6.4
# python-apt                    1.6.5+ubuntu0.3
# python-chess                  0.23.11
# python-dateutil               2.8.1
# python-louvain                0.14
# python-slugify                4.0.1
# python-utils                  2.4.0
# pytz                          2018.9
# pyviz-comms                   0.7.6
# PyWavelets                    1.1.1
# PyYAML                        3.13
# pyzmq                         20.0.0
# qtconsole                     5.0.1
# QtPy                          1.9.0
# regex                         2019.12.20
# requests                      2.23.0
# requests-oauthlib             1.3.0
# resampy                       0.2.2
# retrying                      1.3.3
# rpy2                          3.2.7
# rsa                           4.6
# scikit-image                  0.16.2
# scikit-learn                  0.22.2.post1
# scipy                         1.4.1
# screen-resolution-extra       0.0.0
# scs                           2.1.2
# seaborn                       0.11.0
# Send2Trash                    1.5.0
# setuptools                    50.3.2
# setuptools-git                1.2
# Shapely                       1.7.1
# simplegeneric                 0.8.1
# six                           1.15.0
# sklearn                       0.0
# sklearn-pandas                1.8.0
# slugify                       0.0.1
# smart-open                    3.0.0
# snowballstemmer               2.0.0
# sortedcontainers              2.3.0
# spacy                         2.2.4
# Sphinx                        1.8.5
# sphinxcontrib-serializinghtml 1.1.4
# sphinxcontrib-websupport      1.2.4
# SQLAlchemy                    1.3.20
# sqlparse                      0.4.1
# srsly                         1.0.4
# statsmodels                   0.10.2
# sympy                         1.1.1
# tables                        3.4.4
# tabulate                      0.8.7
# tblib                         1.7.0
# tensorboard                   2.3.0
# tensorboard-plugin-wit        1.7.0
# tensorboardcolab              0.0.22
# tensorflow                    2.3.0
# tensorflow-addons             0.8.3
# tensorflow-datasets           4.0.1
# tensorflow-estimator          2.3.0
# tensorflow-gcs-config         2.3.0
# tensorflow-hub                0.10.0
# tensorflow-metadata           0.25.0
# tensorflow-privacy            0.2.2
# tensorflow-probability        0.11.0
# termcolor                     1.1.0
# terminado                     0.9.1
# testpath                      0.4.4
# text-unidecode                1.3
# textblob                      0.15.3
# textgenrnn                    1.4.1
# Theano                        1.0.5
# thinc                         7.4.0
# tifffile                      2020.9.3
# toml                          0.10.2
# toolz                         0.11.1
# torch                         1.7.0+cu101
# torchsummary                  1.5.1
# torchtext                     0.3.1
# torchvision                   0.8.1+cu101
# tornado                       5.1.1
# tqdm                          4.41.1
# traitlets                     4.3.3
# tweepy                        3.6.0
# typeguard                     2.7.1
# typing-extensions             3.7.4.3
# tzlocal                       1.5.1
# umap-learn                    0.4.6
# uritemplate                   3.0.1
# urllib3                       1.24.3
# vega-datasets                 0.8.0
# wasabi                        0.8.0
# wcwidth                       0.2.5
# webencodings                  0.5.1
# Werkzeug                      1.0.1
# wheel                         0.35.1
# widgetsnbextension            3.5.1
# wordcloud                     1.5.0
# wrapt                         1.12.1
# xarray                        0.15.1
# xgboost                       0.90
# xkit                          0.0.0
# xlrd                          1.1.0
# xlwt                          1.3.0
# yellowbrick                   0.9.1
# zict                          2.0.0
# zipp                          3.4.0

# %% [markdown]
# Подключение к Google Drive

# %%
#подключение к гугл диску
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

path = '/content/drive/My Drive/SeqGAN/'
os.chdir(path)

# %% [markdown]
# Объявление параметров по умолчанию

# %%
from __future__ import print_function
from math import ceil
import numpy as np
import sys

import torch
import torch.optim as optim
import torch.nn as nn

import torch.autograd as autograd
import torch.nn.functional as F
import torch.nn.init as init

import helpers # перетащить функции в код

DATASET = 'coco_image_captions' # название выборки данных список выборок: ['stihi_ru', 'coco_image_captions']
CUDA = True # использование cuda (gpu/tpu): True/False
BATCH_SIZE = 1000 # количество примеров в партии/батче
MLE_TRAIN_EPOCHS = 30 # количество эпох при обучении генератора на основе MLE
DIS_TRAIN_ITERATIONS = 300 # количество итераций при обучении дискриминатора (итерации содержит несколько эпох, на каждой итерации данные для обучения обновляются)
DIS_TRAIN_EPOCHS = 1 # количество эпох в одной итерации обучения дискриминатора
ADV_TRAIN_EPOCHS = 25 # количество эпох при обучении генератора на основе соревновательного обучения / обучения с подкреплением
POS_NEG_SAMPLES = 10000

GEN_EMBEDDING_DIM = 150 # ширина слоя Embedding генератора
GEN_HIDDEN_DIM = 150 # количество нейронов в слоях генератора
DIS_EMBEDDING_DIM = 150 # ширина слоя Embedding дискриминатора
DIS_HIDDEN_DIM = 150 # количество нейронов в слоях дискриминатора

# параметры START_LETTER, VOCAB_SIZE, MAX_SEQ_LEN и FILE_PATHS задаются автоматически ниже
START_LETTER = None #! стартовое слово (слово которое подается первым на нейронную сеть генератор)
MAX_SEQ_LEN = None # длина генерируемого примера
VOCAB_SIZE = None # количество слов в словаре
FILE_PATHS = None # пути к файлам набора данных
CLOSING_WORD = None # заключительное слово / слово заполнитель ставящееся в конце предложения

# выбор набора данных и инициализация соответствующих глобальных параметров
if DATASET == 'stihi_ru': # выборка с русскими стихами с сайта stihi_ru (длина примера 10 слов, размер словаря 5 000 слов)
  START_LETTER = 0
  MAX_SEQ_LEN = 10
  VOCAB_SIZE = 5000
  CLOSING_WORD = 4999#4997
  FILE_PATHS = {'train': r'datasets/stihi_ru/stihi_ru_realtrain_cotra.txt', 'test': r'datasets/stihi_ru/stihi_ru_realtest_coco.txt',
                'vocab': r'datasets/stihi_ru/stihi_ru_vocab_cotra.pkl', 'saved_models': r'saved_models/stihi_ru'}
elif DATASET == 'coco_image_captions': # выборка COCO Image Captions (длина примера 20 слов, размер словаря 4980 слов)
  START_LETTER = 0
  MAX_SEQ_LEN = 20
  VOCAB_SIZE = 4838
  CLOSING_WORD = 1814
  FILE_PATHS = {'train': r'datasets/coco_image_captions/coco_image_captions_train.txt', 'test': r'datasets/coco_image_captions/coco_image_captions_test.txt',
                'vocab': r'datasets/coco_image_captions/coco_image_captions_vocab_cotra_test.pkl', 'saved_models': r'saved_models/coco_image_captions'}

# %% [markdown]
# Инициализация генераторов случайных чисел.

# %%
# инициализация генераторов случайных чисел.
torch.random.manual_seed(50)
np.random.seed(50)
#системный рандом!!!

# %% [markdown]
# Объявление класса Генератора

# %%
class Generator(nn.Module):

  def __init__(self, embedding_dim, hidden_dim, vocab_size, max_seq_len, gpu=False):
    super(Generator, self).__init__()
    self.hidden_dim = hidden_dim # количество элементов на скрытом слое
    self.embedding_dim = embedding_dim # размер слоя embedding
    self.max_seq_len = max_seq_len # длина генерируемых примеров
    self.vocab_size = vocab_size # размер словаря использующегося при генерации
    self.gpu = gpu # использование cuda (True/False)
    self.lstm_num_layers = 1 # количество LSTM слоев

    self.embeddings = nn.Embedding(vocab_size, embedding_dim) # объявление слоя embeddings
    self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers=self.lstm_num_layers) # объявление LSTM слоев
    self.lstm2out = nn.Linear(hidden_dim, vocab_size) # объявление выходного слоя

  def init_hidden(self, batch_size=1):
    # инициализация состояния LSTM слоев
    h = autograd.Variable(torch.zeros(self.lstm_num_layers, batch_size, self.hidden_dim)) 
    c = autograd.Variable(torch.zeros(self.lstm_num_layers, batch_size, self.hidden_dim))

    if self.gpu:
        return h.cuda(), c.cuda()
    else:
        return h, c

  def forward(self, inp, hidden, c):
    """
    Embeds input and applies LSTM one token at a time (seq_len = 1)
    """
    # input dim                                             # batch_size
    emb = self.embeddings(inp)                              # batch_size x embedding_dim
    emb = emb.view(1, -1, self.embedding_dim)               # 1 x batch_size x embedding_dim
    out, (hidden, c) = self.lstm(emb, (hidden, c))                    # 1 x batch_size x hidden_dim (out)
    out = self.lstm2out(out.view(-1, self.hidden_dim))       # batch_size x vocab_size
    out = F.log_softmax(out, dim=1)
    return out, hidden, c

  def sample(self, num_samples, start_letter=0, degree=1):
    """
    Samples the network and returns num_samples samples of length max_seq_len.

    Outputs: samples, hidden
        - samples: num_samples x max_seq_length (a sampled sequence in each row)
    """

    samples = torch.zeros(num_samples, self.max_seq_len).type(torch.LongTensor)

    h, c = self.init_hidden(num_samples)
    inp = autograd.Variable(torch.LongTensor([start_letter]*num_samples))
    if self.gpu:
        samples = samples.cuda()
        inp = inp.cuda()

    for i in range(self.max_seq_len):
        out, h, c = self.forward(inp, h, c)               # out: num_samples x vocab_size
        out = torch.exp(out)**degree
        out = torch.multinomial(out, 1)  # num_samples x 1 (sampling from each row)
        samples[:, i] = out.view(-1).data

        inp = out.view(-1)

    return samples

  def batchNLLLoss(self, inp, target):
    """
    Returns the NLL Loss for predicting target sequence.

    Inputs: inp, target
        - inp: batch_size x seq_len
        - target: batch_size x seq_len

        inp should be target with <s> (start letter) prepended
    """

    loss_fn = nn.NLLLoss()
    batch_size, seq_len = inp.size()
    inp = inp.permute(1, 0)           # seq_len x batch_size
    target = target.permute(1, 0)     # seq_len x batch_size
    h, c = self.init_hidden(batch_size)

    loss = 0
    for i in range(seq_len):
        out, h, c = self.forward(inp[i], h, c)
        loss += loss_fn(out, target[i])

    return loss     # per batch

  def batchPGLoss(self, inp, target, reward):
    """
    Returns a pseudo-loss that gives corresponding policy gradients (on calling .backward()).
    Inspired by the example in http://karpathy.github.io/2016/05/31/rl/

    Inputs: inp, target
        - inp: batch_size x seq_len
        - target: batch_size x seq_len
        - reward: batch_size (discriminator reward for each sentence, applied to each token of the corresponding
                  sentence)

        inp should be target with <s> (start letter) prepended
    """

    batch_size, seq_len = inp.size()
    inp = inp.permute(1, 0)          # seq_len x batch_size
    target = target.permute(1, 0)    # seq_len x batch_size
    h, c = self.init_hidden(batch_size)

    loss = 0
    for i in range(seq_len):
        out, h, c = self.forward(inp[i], h, c)
        # TODO: should h be detached from graph (.detach())?
        for j in range(batch_size):
            loss += -out[j][target.data[i][j]]*reward[j]#     # log(P(y_t|Y_1:Y_{t-1})) * Q

    return loss/batch_size

# %% [markdown]
# Объявяление класса Дискриминатора

# %%
class Discriminator(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, max_seq_len, gpu=False, dropout=0.2):
        super(Discriminator, self).__init__()
        self.hidden_dim = hidden_dim # размер скрытого слоя
        self.embedding_dim = embedding_dim # ширина слоя embedding
        self.max_seq_len = max_seq_len # длина входного примера
        self.gpu = gpu # использование cuda (True/False)

        self.embeddings = nn.Embedding(vocab_size, embedding_dim) # объявление слоя Embedding
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers=3, bidirectional=True, dropout=dropout) # объявление LSTM слоев

        self.lstm2hidden = nn.Linear(2*3*hidden_dim, hidden_dim) # объявление скрытого слоя
        # self.lstm2hidden = nn.Linear(max_seq_len*hidden_dim*2, hidden_dim) # объявление скрытого слоя

        self.dropout_linear = nn.Dropout(p=dropout)
        self.hidden2out = nn.Linear(hidden_dim, 1) # объявление выходного слоя

    def init_hidden(self, batch_size):
        # инициализация LSTM слоев
        h = autograd.Variable(torch.zeros(2*3*1, batch_size, self.hidden_dim))
        c = autograd.Variable(torch.zeros(2*3*1, batch_size, self.hidden_dim))

        if self.gpu:
            return h.cuda(), c.cuda()
        else:
            return h, c

    def forward(self, input, hidden, c):
        # input dim                                                # batch_size x seq_len
        # print(input.shape)
        emb = self.embeddings(input)                               # batch_size x seq_len x embedding_dim
        # print(emb.shape)
        emb = emb.permute(1, 0, 2)                                 # seq_len x batch_size x embedding_dim
        # print(emb.shape)
        out_lstm, (hidden, c) = self.lstm(emb, (hidden, c))                          # 4 x batch_size x hidden_dim

        hidden = hidden.permute(1, 0, 2).contiguous()              # batch_size x 4 x hidden_dim
        # hidden = out_lstm
        # print(hidden.shape, hidden.view(-1, self.max_seq_len*self.hidden_dim).shape)
        # print(hidden.permute(1, 0, 2).contiguous().shape, hidden.permute(1, 0, 2).contiguous().view(-1, self.max_seq_len*self.hidden_dim*2).shape)

        out = self.lstm2hidden(hidden.view(-1, 6*self.hidden_dim))  # batch_size x 4*hidden_dim
        # out = self.lstm2hidden(hidden.view(-1, self.max_seq_len*self.hidden_dim*2))  # batch_size x 4*hidden_dim
        
        out = torch.relu(out)
        # out = out * torch.sigmoid(0.1 * out) # функция активации Swish: x * sigmoid(b*x)
        out = self.dropout_linear(out)
        out = self.hidden2out(out)                                 # batch_size x 1
        out = torch.sigmoid(out)
        return out

    def batchClassify(self, inp):
        """
        Classifies a batch of sequences.

        Inputs: inp
            - inp: batch_size x seq_len

        Returns: out
            - out: batch_size ([0,1] score)
        """

        h, c = self.init_hidden(inp.size()[0])
        out = self.forward(inp, h, c)
        return out.view(-1)

    def batchBCELoss(self, inp, target):
        """
        Returns Binary Cross Entropy Loss for discriminator.

         Inputs: inp, target
            - inp: batch_size x seq_len
            - target: batch_size (binary 1/0)
        """

        loss_fn = nn.BCELoss()
        h, c = self.init_hidden(inp.size()[0])
        out = self.forward(inp, h, c)
        return loss_fn(out, target)

# %% [markdown]
# Объявление функций возвращающих данные

# %%
# функция генерации реалиных данных
def sampler_example(batch_size):
  x = data_file_train[np.random.randint(0, len(data_file_train), batch_size)]
  y = np.concatenate([x[:, 1:], np.zeros([batch_size, 1])+VOCAB_SIZE-2], axis=-1)
  return x, y

# функция генерации реалиных данных
def sampler_example_test(batch_size):
  x = data_file_test[np.random.randint(0, len(data_file_test), batch_size)]
  y = np.concatenate([x[:, 1:], np.zeros([batch_size, 1])+VOCAB_SIZE-2], axis=-1)
  return x, y

# %% [markdown]
# Функции обучения генератора

# %%
# функция обучения генератора на основе MLE
def train_generator_MLE(gen, gen_opt, real_samples_train, real_samples_test, epochs):
    """
    Max Likelihood Pretraining for the generator
    """
    for epoch in range(epochs):
        print('epoch %d : ' % (epoch + 1), end='')
        sys.stdout.flush()
        total_loss = 0

        # обучение
        for i in range(0, len(real_samples_train), BATCH_SIZE):
            inp_train, target_train = helpers.prepare_generator_batch(real_samples_train[i:i + BATCH_SIZE], start_letter=START_LETTER,
                                                          gpu=CUDA)
            gen_opt.zero_grad()
            loss = gen.batchNLLLoss(inp_train, target_train)
            loss.backward()
            gen_opt.step()

            total_loss += loss.data.item()

            if (i / BATCH_SIZE) % ceil(
                            ceil(len(real_samples_train) / float(BATCH_SIZE)) / 10.) == 0:  # roughly every 10% of an epoch
                print('.', end='')
                sys.stdout.flush()

        # each loss in a batch is loss per sample
        total_loss = total_loss / ceil(len(real_samples_train) / float(BATCH_SIZE)) / MAX_SEQ_LEN
        print(' average_train_NLL = %.4f' % total_loss, end='')

        # тестирование
        test_loss = 0

        for i in range(0, len(real_samples_test), BATCH_SIZE):
            inp_test, target_test = helpers.prepare_generator_batch(real_samples_test[i:i + BATCH_SIZE], start_letter=START_LETTER,
                                                              gpu=CUDA)
            loss = gen.batchNLLLoss(inp_test, target_test)
            test_loss += loss.data.item()
        test_loss = test_loss / ceil(len(real_samples_test) / float(BATCH_SIZE)) / MAX_SEQ_LEN
        print(' average_test_NLL = %.4f' % test_loss)

def test_mle(gen, real_samples_train, real_samples_test):
  '''
  Тестирование генератора на обучающей и тестовой выборках.
  '''
  # тестирование на обучающей
  test_loss = 0
  for i in range(0, len(real_samples_train), BATCH_SIZE):
      inp_test, target_test = helpers.prepare_generator_batch(real_samples_train[i:i + BATCH_SIZE], start_letter=START_LETTER,
                                                        gpu=CUDA)
      loss = gen.batchNLLLoss(inp_test, target_test)
      test_loss += loss.data.item()
  test_loss = test_loss / ceil(len(real_samples_train) / float(BATCH_SIZE)) / MAX_SEQ_LEN
  print('average_train_NLL = %.4f' % test_loss, end='')

  # тестирование на тестовой
  test_loss = 0
  for i in range(0, len(real_samples_test), BATCH_SIZE):
      inp_test, target_test = helpers.prepare_generator_batch(real_samples_test[i:i + BATCH_SIZE], start_letter=START_LETTER,
                                                        gpu=CUDA)
      loss = gen.batchNLLLoss(inp_test, target_test)
      test_loss += loss.data.item()
  test_loss = test_loss / ceil(len(real_samples_test) / float(BATCH_SIZE)) / MAX_SEQ_LEN
  print(' average_test_NLL = %.4f' % test_loss)

# функция обучения генератора на основе обучения с подкреплением RL
def train_generator_PG(gen, gen_opt, dis, num_batches): # !переименовать!
    """
    The generator is trained using policy gradients, using the reward from the discriminator.
    Training is done for num_batches batches.
    """

    for batch in range(num_batches):
        s = gen.sample(BATCH_SIZE*4)        # 64 works best
        inp, target = helpers.prepare_generator_batch(s, start_letter=START_LETTER, gpu=CUDA)
        rewards = dis.batchClassify(target)

        gen_opt.zero_grad()
        pg_loss = gen.batchPGLoss(inp, target, rewards)
        pg_loss.backward()
        gen_opt.step()
    print()

# %% [markdown]
# Функция обучения дискриминатора

# %%
# функция обучения дискриминатора
def train_discriminator(discriminator, dis_opt, real_data_samples, generator, d_steps, epochs):
    """
    Training the discriminator on real_data_samples (positive) and generated samples from generator (negative).
    Samples are drawn d_steps times, and the discriminator is trained for epochs epochs.
    """

    # generating a small validation set before training
    pos_val = real_data_samples[np.random.randint(0, len(real_data_samples), 500)] #sampler_example(250)
    neg_val = generator.sample(500)
    val_inp, val_target = helpers.prepare_discriminator_data(pos_val, neg_val, gpu=CUDA)

    for d_step in range(d_steps):
        s = helpers.batchwise_sample(generator, POS_NEG_SAMPLES, BATCH_SIZE)
        dis_inp, dis_target = helpers.prepare_discriminator_data(real_data_samples, s, gpu=CUDA)
        val_pred = discriminator.batchClassify(val_inp)
        print('ДО ОБУЧЕНИЯ: val_acc = %.4f' % (
            torch.sum((val_pred>0.5)==(val_target>0.5)).data.item()/1000.))
        for epoch in range(epochs):
            print('d-step %d epoch %d : ' % (d_step + 1, epoch + 1), end='')
            sys.stdout.flush()
            total_loss = 0
            total_acc = 0

            for i in range(0, 2 * POS_NEG_SAMPLES, BATCH_SIZE):
                inp, target = dis_inp[i:i + BATCH_SIZE], dis_target[i:i + BATCH_SIZE]
                dis_opt.zero_grad()
                out = discriminator.batchClassify(inp)
                loss_fn = nn.BCELoss()
                loss = loss_fn(out, target)
                loss.backward()
                dis_opt.step()

                total_loss += loss.data.item()
                total_acc += torch.sum((out>0.5)==(target>0.5)).data.item()

                if (i / BATCH_SIZE) % ceil(ceil(2 * POS_NEG_SAMPLES / float(
                        BATCH_SIZE)) / 10.) == 0:  # roughly every 10% of an epoch
                    print('.', end='')
                    sys.stdout.flush()

            total_loss /= ceil(2 * POS_NEG_SAMPLES / float(BATCH_SIZE))
            total_acc /= float(2 * POS_NEG_SAMPLES)

            val_pred = discriminator.batchClassify(val_inp)
            print(' average_loss = %.4f, train_acc = %.4f, val_acc = %.4f' % (
                total_loss, total_acc, torch.sum((val_pred>0.5)==(val_target>0.5)).data.item()/1000.))

# %% [markdown]
# Функция оценки качества генерации текста

# %%
# оценка качества по BLEU метрике
from nltk.translate.bleu_score import SmoothingFunction
from nltk.translate.bleu_score import sentence_bleu
from datetime import datetime
import nltk
import random
from scipy import stats

# функция оценки качества генерации текста по метрике BLEU
def BLEU(reference_sample, test_sample, print_iteration=100, flag_print=True):
  if flag_print:
    print("--- --- ---\nStart BLEU")
  pad = CLOSING_WORD
  #################################################
  reference = []
  for line in reference_sample:
    candidate = []
    for i in line:
      if i == pad:
        break
      candidate.append(i)

    reference.append(candidate)
  #################################################
  hypothesis_list_leakgan = []
  for line in test_sample:
    while line[-1] == str(pad):
      line.remove(str(pad))
    hypothesis_list_leakgan.append(line)
  #################################################
  random.shuffle(hypothesis_list_leakgan)
  #################################################

  smoothing_function = SmoothingFunction().method1

  mass_bleu = []
  for ngram in range(2,6):
      weight = tuple((1. / ngram for _ in range(ngram)))
      bleu_leakgan = []
      bleu_supervise = []
      bleu_base2 = []
      num = 0
      for h in hypothesis_list_leakgan:
          BLEUscore = nltk.translate.bleu_score.sentence_bleu(reference, h, weight, smoothing_function = smoothing_function)
          num += 1
          bleu_leakgan.append(BLEUscore)

          if num%print_iteration == 0 and flag_print:
            print(ngram, num, sum(bleu_leakgan)/len(bleu_leakgan))
          
      mass_bleu.append(1.0 * sum(bleu_leakgan) / len(bleu_leakgan))
      if flag_print:
        print('--- --- ---')
        print(len(weight), '-gram BLEU score : ', 1.0 * sum(bleu_leakgan) / len(bleu_leakgan), "\n")
  return mass_bleu

# %% [markdown]
# Функция сохранения моделей

# %%
# функция сохранения моделей (сериализация: моделей генератора и дискриминатора, параметров по умолчанию, обучающих данных)
def save_models(data_file_tensor_train, gen, dis, gen_optimizer, dis_optimizer, name):
  state = {
      'default_parameters': {'VOCAB_SIZE': VOCAB_SIZE, 'MAX_SEQ_LEN': MAX_SEQ_LEN, 'GEN_EMBEDDING_DIM': GEN_EMBEDDING_DIM,
                             'GEN_HIDDEN_DIM': GEN_HIDDEN_DIM, 'DIS_EMBEDDING_DIM': DIS_EMBEDDING_DIM, 'DIS_HIDDEN_DIM': DIS_HIDDEN_DIM},
      'data_file_tensor_train': data_file_tensor_train,
      'gen_state_dict': gen.state_dict(),
      'dis_state_dict': dis.state_dict(),
      'gen_optimizer': gen_optimizer.state_dict(),
      'dis_optimizer': dis_optimizer.state_dict(),
  }
  torch.save(state, name)

# %% [markdown]
# Функция загрузки моделей

# %%
# функция загрузки моделей (десериализация: моделей генератора и дискриминатора, параметров по умолчанию, обучающих данных)
def load_models(name):
  if CUDA:
    device = torch.device('cuda')
  else:
    device = torch.device('cpu')

  print('state')
  state = torch.load(name, map_location=device)

  print('default_parameters')
  VOCAB_SIZE = state['default_parameters']['VOCAB_SIZE']
  MAX_SEQ_LEN = state['default_parameters']['MAX_SEQ_LEN']
  GEN_EMBEDDING_DIM = state['default_parameters']['GEN_EMBEDDING_DIM']
  GEN_HIDDEN_DIM = state['default_parameters']['GEN_HIDDEN_DIM']
  DIS_EMBEDDING_DIM = state['default_parameters']['DIS_EMBEDDING_DIM']
  DIS_HIDDEN_DIM = state['default_parameters']['DIS_HIDDEN_DIM']

  print('data_file_tensor_train')
  data_file_tensor_train = torch.tensor(state['data_file_tensor_train'])

  print('Generator')
  gen = Generator(GEN_EMBEDDING_DIM, GEN_HIDDEN_DIM, VOCAB_SIZE, MAX_SEQ_LEN, gpu=CUDA)
  gen.load_state_dict(state['gen_state_dict'])
  gen_optimizer = optim.Adam(gen.parameters(), lr=0.001)
  gen_optimizer.load_state_dict(state['gen_optimizer'])

  print('Discriminator')
  dis = Discriminator(DIS_EMBEDDING_DIM, DIS_HIDDEN_DIM, VOCAB_SIZE, MAX_SEQ_LEN, gpu=CUDA)
  dis.load_state_dict(state['dis_state_dict'])
  dis_optimizer = optim.Adagrad(dis.parameters())
  dis_optimizer.load_state_dict(state['dis_optimizer'])

  print('CUDA')
  if CUDA:
    data_file_tensor_train = data_file_tensor_train.cuda()
    gen = gen.cuda()
    dis = dis.cuda()
  
  return [data_file_tensor_train, gen, dis, gen_optimizer, dis_optimizer,
          VOCAB_SIZE, MAX_SEQ_LEN, GEN_EMBEDDING_DIM, GEN_HIDDEN_DIM, DIS_EMBEDDING_DIM, DIS_HIDDEN_DIM]

# %% [markdown]
# Загрузка набора данных

# %%
# загрузка словаря
import pickle

vocab_file = FILE_PATHS['vocab']
word, vocab = pickle.load(open(vocab_file, 'rb'))

# %%
# загрузка обучающей выборки
f = open(FILE_PATHS['train'], 'r')
data_file_train = []
for line in f:
  line = line.replace('\n', '')
  line = line.split()
  for i in range(len(line)):
    line[i] = int(line[i])
  data_file_train.append(line)
data_file_train = np.array(data_file_train)[:, :MAX_SEQ_LEN]
print("Примеров в обучающей выборке: ", len(data_file_train))
# Out:
# Примеров в обучающей выборке:  80000

# %%
# загрузка тестовой выборки
f = open(FILE_PATHS['test'], 'r')
data_file_test = []
for line in f:
  line = line.replace('\n', '')
  line = line.split()
  for i in range(len(line)):
    line[i] = int(line[i])
  data_file_test.append(line)
data_file_test = np.array(data_file_test)[:, :MAX_SEQ_LEN]
print("Примеров в тестовой выборке: ", len(data_file_test))
# Out:
# Примеров в тестовой выборке:  5000

# %%
# примеры из обучающей выборки
print("Примеры из обучающей выборки")
samples = sampler_example(50)[0]
output_function = []
for samp in samples:
  line = [word[x] for x in samp]
  line = ' '.join(line)
  output_function.append(line)

for i, output in enumerate(output_function):
  print("#", i, "\tПример: ", output)
# Out:
# Примеры из обучающей выборки
# # 0 	Пример:  A street in front of an airport with people going in the entrance .
# # 1 	Пример:  Blue and green bird sitting on the ground next to plants .
# # 2 	Пример:  A racer is sitting on a horse in the gates .
# # 3 	Пример:  A man skiing a jump , while in the background there is snow melting off the slopes .
# # 4 	Пример:  A man that is holding a knife and a pot with broccoli .
# # 5 	Пример:  A bed in a bedroom that has lots of things sitting on top of it .
# # 6 	Пример:  A skateboarder does a handstand trick on a skate - ramp .
# # 7 	Пример:  A tall white building with three vehicles parked in front of it .
# # 8 	Пример:  A man admiring a black and yellow motorcycle on a white background .
# # 9 	Пример:  A cup of soup , a sandwich and a sweet roll on a table .
# # 10 	Пример:  Traffic on a busy city road with street lights and Christmas decorations .
# # 11 	Пример:  The woman is eating a hot dog at the game .
# # 12 	Пример:  A bright neon colored bus with no wheels sitting on some rocks .
# # 13 	Пример:  Two figures in the dark under umbrellas with a light shining on them .
# # 14 	Пример:  A dog in a field of grass with its tongue out .
# # 15 	Пример:  Tennis player about to deliver backhand to ball during match .
# # 16 	Пример:  A pair of young men stand in a field playing with a frisbee .
# # 17 	Пример:  A crowd of people standing underneath a snow covered mountain .
# # 18 	Пример:  A young boy tossing a green Frisbee in a park .
# # 19 	Пример:  A view of a bunch of street lights , during a cloudy day .
# # 20 	Пример:  A brown and white horse standing in front of a red wall .
# # 21 	Пример:  The two skiers have on all the gear needed to ski .
# # 22 	Пример:  Two girls in black , one in pants and one is a skirt , huddle under a black umbrella .
# # 23 	Пример:  A person performing a riding trick on a skate board .
# # 24 	Пример:  A commercial airliners taxis toward the runway for take - off .
# # 25 	Пример:  Sun shines through on a bathroom with a pedestal sink .
# # 26 	Пример:  A plate full of food including broccoli , potatoes and tomatoes .
# # 27 	Пример:  A couple of little girls standing next to each other .
# # 28 	Пример:  An open face sandwich and a pile of potato chips on a plate .
# # 29 	Пример:  A stop sign with the word war added beneath it .
# # 30 	Пример:  A baby brushing it ' s teeth with a blue and white tooth brush .
# # 31 	Пример:  An intersection of two city streets on a rainy day .
# # 32 	Пример:  A man and woman dressed in wedding attire walking out of a building together .
# # 33 	Пример:  Boys stand with skateboards watching others skate at a skatepark .
# # 34 	Пример:  A close shot of a shirt with a tie is seen .
# # 35 	Пример:  The sun shines over a mountain as a skier glides down a snowy slope .
# # 36 	Пример:  A young boy sitting on a couch with a tooth brush in his mouth .
# # 37 	Пример:  A train cake , apparently for somebody ' s second birthday .
# # 38 	Пример:  Three men stand with ski poles on a snowy mountain .
# # 39 	Пример:  This is a living room with a black , white , and maroon colored tile floor .
# # 40 	Пример:  An intersection with a fast food restaurant on the opposite corner .
# # 41 	Пример:  A cat is laying on the top of a refrigerator in a kitchen .
# # 42 	Пример:  Skateboarder riding in a concrete with a large cross in the middle .
# # 43 	Пример:  A picture of a boat that is in the water .
# # 44 	Пример:  A close - up of the face of the horse with a woman on the back .
# # 45 	Пример:  A man riding a skateboard on top of a sidewalk .
# # 46 	Пример:  A man is riding a wave on his surf board .
# # 47 	Пример:  A bathroom under construction with white tile beside a bedroom .
# # 48 	Пример:  A child rests on a fire hydrant while on the street with a woman .
# # 49 	Пример:  Five people sitting on a long bench in the city .

# %% [markdown]
# Оценка качества примеров из обучающей выборки на основе BLEU  (для сравнения с генератором)

# %%
# %%time
# оценка качества на основе примеров из обучающей выборки (для сравнения с генератором)
print("Оценка примеров из обучающей выборки на основе BLEU")
BLEU(data_file_test.tolist(), data_file_train[:500].tolist(), print_iteration=100)

'''
BLEU примеров из обучающей выборки
--- --- ---
Start BLEU
2 100 0.5365504958995001
2 200 0.5426700180034696
2 300 0.5425210147596119
2 400 0.5438925313146432
2 500 0.5499117864293879
--- --- ---
2 -gram BLEU score :  0.5499117864293879
3 100 0.4252853298296578
3 200 0.4294441261529973
3 300 0.42938411299670276
3 400 0.432946142036555
3 500 0.436991427933691
--- --- ---
3 -gram BLEU score :  0.436991427933691
4 100 0.3118228221158724
4 200 0.31347352868277367
4 300 0.3133847969805193
4 400 0.3148005592801212
4 500 0.3173224414085976
--- --- ---
4 -gram BLEU score :  0.3173224414085976
5 100 0.20748007111715946
5 200 0.21057918753505803
5 300 0.20884027925072032
5 400 0.20986772415037908
5 500 0.21083373415979106
--- --- ---
5 -gram BLEU score :  0.21083373415979106
'''
# Out:
# Оценка примеров из обучающей выборки на основе BLEU
# --- --- ---
# Start BLEU
# 2 100 0.5570250679278492
# 2 200 0.556688037824323
# 2 300 0.5493089304838155
# 2 400 0.5494658337492588
# 2 500 0.5499117864293878
# --- --- ---
# 2 -gram BLEU score :  0.5499117864293878
#
# 3 100 0.44196089553285683
# 3 200 0.447768125311308
# 3 300 0.43858963216173663
# 3 400 0.4372307787789591
# 3 500 0.43699142793369133
# --- --- ---
# 3 -gram BLEU score :  0.43699142793369133
#
# 4 100 0.31414379080893645
# 4 200 0.3275024883519048
# 4 300 0.3213421972239594
# 4 400 0.3174880435602007
# 4 500 0.31732244140859767
# --- --- ---
# 4 -gram BLEU score :  0.31732244140859767
#
# 5 100 0.21122823761654302
# 5 200 0.21973281984255646
# 5 300 0.21605178827556978
# 5 400 0.21085774538348726
# 5 500 0.2108337341597913
# --- --- ---
# 5 -gram BLEU score :  0.2108337341597913
#
# CPU times: user 7min 58s, sys: 52.6 ms, total: 7min 58s
# Wall time: 7min 58s

# %% [markdown]
# Создание нейронных сетей генератора и дискриминатора

# %%
# объявление нейронных сетей генератора и дискриминатора, подготовка выборок данных для использования pytorch
gen = Generator(GEN_EMBEDDING_DIM, GEN_HIDDEN_DIM, VOCAB_SIZE, MAX_SEQ_LEN, gpu=CUDA)
dis = Discriminator(DIS_EMBEDDING_DIM, DIS_HIDDEN_DIM, VOCAB_SIZE, MAX_SEQ_LEN, gpu=CUDA)

if CUDA:
  gen = gen.cuda()
  dis = dis.cuda()
  data_file_tensor_train = torch.tensor(data_file_train).cuda()
  data_file_tensor_test = torch.tensor(data_file_test).cuda()
else:
  data_file_tensor_train = torch.tensor(data_file_train)
  data_file_tensor_test = torch.tensor(data_file_test)

gen_optimizer = optim.Adam(gen.parameters(), lr=0.001) #, lr=0.001
dis_optimizer = optim.Adagrad(dis.parameters())

# %% [markdown]
# Обучение генератора на основе MLE

# %%
# %%time
test_mle(gen, data_file_tensor_train, data_file_tensor_test)
# Out:
# average_train_NLL = 8.5446 average_test_NLL = 8.5451
# CPU times: user 1.3 s, sys: 397 ms, total: 1.7 s
# Wall time: 1.8 s

# %%
# %%time
# обучение генератора на основе MLE / предобучение генератора
print('Запуск обучения генератора на основе MLE...')
gen_optimizer = optim.Adam(gen.parameters())#, lr=0.0002
train_generator_MLE(gen, gen_optimizer, data_file_tensor_train, data_file_tensor_test, MLE_TRAIN_EPOCHS) # MLE_TRAIN_EPOCHS

test_mle(gen, data_file_tensor_train, data_file_tensor_test)
# сохранение результата обучения
save_models(data_file_tensor_train, gen, dis, gen_optimizer, dis_optimizer,
            FILE_PATHS['saved_models'] + r'/' + r'seqgan_mle.pytorch')
# epoch 1 : .......... average_train_NLL = 1.8447 average_test_NLL = 1.9937
# Out:
# Запуск обучения генератора на основе MLE...
# epoch 1 : .......... average_train_NLL = 4.5138 average_test_NLL = 3.3173
# epoch 2 : .......... average_train_NLL = 3.0475 average_test_NLL = 2.9099
# epoch 3 : .......... average_train_NLL = 2.7634 average_test_NLL = 2.7012
# epoch 4 : .......... average_train_NLL = 2.5905 average_test_NLL = 2.5820
# epoch 5 : .......... average_train_NLL = 2.4759 average_test_NLL = 2.4898
# epoch 6 : .......... average_train_NLL = 2.3922 average_test_NLL = 2.4348
# epoch 7 : .......... average_train_NLL = 2.3276 average_test_NLL = 2.3860
# epoch 8 : .......... average_train_NLL = 2.2767 average_test_NLL = 2.3403
# epoch 9 : .......... average_train_NLL = 2.2326 average_test_NLL = 2.3062
# epoch 10 : .......... average_train_NLL = 2.1932 average_test_NLL = 2.2736
# epoch 11 : .......... average_train_NLL = 2.1576 average_test_NLL = 2.2472
# epoch 12 : .......... average_train_NLL = 2.1273 average_test_NLL = 2.2134
# epoch 13 : .......... average_train_NLL = 2.0967 average_test_NLL = 2.1897
# epoch 14 : .......... average_train_NLL = 2.0708 average_test_NLL = 2.1588
# epoch 15 : .......... average_train_NLL = 2.0448 average_test_NLL = 2.1387
# epoch 16 : .......... average_train_NLL = 2.0203 average_test_NLL = 2.1249
# epoch 17 : .......... average_train_NLL = 1.9998 average_test_NLL = 2.1043
# epoch 18 : .......... average_train_NLL = 1.9795 average_test_NLL = 2.0884
# epoch 19 : .......... average_train_NLL = 1.9593 average_test_NLL = 2.0754
# epoch 20 : .......... average_train_NLL = 1.9408 average_test_NLL = 2.0592
# epoch 21 : .......... average_train_NLL = 1.9224 average_test_NLL = 2.0461
# epoch 22 : .......... average_train_NLL = 1.9051 average_test_NLL = 2.0338
# epoch 23 : .......... average_train_NLL = 1.8887 average_test_NLL = 2.0233
# epoch 24 : .......... average_train_NLL = 1.8735 average_test_NLL = 2.0136
# epoch 25 : .......... average_train_NLL = 1.8589 average_test_NLL = 2.0049
# epoch 26 : .......... average_train_NLL = 1.8453 average_test_NLL = 1.9942
# epoch 27 : .......... average_train_NLL = 1.8322 average_test_NLL = 1.9856
# epoch 28 : .......... average_train_NLL = 1.8196 average_test_NLL = 1.9764
# epoch 29 : .......... average_train_NLL = 1.8075 average_test_NLL = 1.9678
# epoch 30 : .......... average_train_NLL = 1.7959 average_test_NLL = 1.9609
# average_train_NLL = 1.8009 average_test_NLL = 1.9609
# CPU times: user 1min 54s, sys: 34.7 s, total: 2min 29s
# Wall time: 2min 31s

# %%
# %%time
test_mle(gen, data_file_tensor_train, data_file_tensor_test)
# Out:
# average_train_NLL = 1.8009 average_test_NLL = 1.9609
# CPU times: user 1.41 s, sys: 327 ms, total: 1.74 s
# Wall time: 1.75 s

# %% [markdown]
# Генерация примеров текстов на основе MLE

# %%
# примеры сгенерированных текстов
print("Примеры генерируемых текстов на основе MLE")
degree = 1
print("Degree:", degree)
samples = gen.sample(50, degree=degree).cpu().detach().numpy()

output_function = []
for i, samp in enumerate(samples):
  line = [word[x] for x in samp]
  line = ' '.join(line)
  output_function.append(line)
  bleu = BLEU(data_file_test.tolist(), [samp], flag_print=False)
  print("#", i, "\tПример: ", line, ' '*(100-len(line)), '\tОценка: ', bleu)
# Out:
# Примеры генерируемых текстов на основе MLE
# Degree: 1
# # 0 	Пример:  The train traveling down the track on town track just set out of the park .                           	Оценка:  [0.5803810000880093, 0.4539847774172143, 0.1531682455208201, 0.08078132896612913]
# # 1 	Пример:  The fence sitting inside the bathroom surrounded by trees and tube .                                  	Оценка:  [0.41675437673324534, 0.268229131353767, 0.10322080150552766, 0.05891010340986106]
# # 2 	Пример:  A train moving tracks next to a wooden size platform in the country in a dimly environment .          	Оценка:  [0.6529286250990105, 0.4558685532582043, 0.2732231510487644, 0.12834826432879642]
# # 3 	Пример:  A woman on the tennis court preparing to hit with a bat .                                             	Оценка:  [0.4893604849295929, 0.34174500988297, 0.22012248449054683, 0.1079711005739161]
# # 4 	Пример:  A cat is sitting on a train along with many other riders ' s figurine .                               	Оценка:  [0.6282808624375432, 0.5086223840955505, 0.3903594390682207, 0.31085206075418725]
# # 5 	Пример:  Many girls play children are standing at the train goes .                                             	Оценка:  [0.3402785236893603, 0.2343197292238376, 0.16586105071157164, 0.08609373184361885]
# # 6 	Пример:  A dog sitting on the side of a brown bed next to a computer equipment .                               	Оценка:  [0.7398435111918139, 0.6724640591076463, 0.572370695651743, 0.4222055277665569]
# # 7 	Пример:  A big giraffe are tied to eat a bottle of wine .                                                      	Оценка:  [0.533113989983183, 0.3982378626139663, 0.293597382795084, 0.21546550289591512]
# # 8 	Пример:  A photo of a girl with young kites in waves .                                                         	Оценка:  [0.39735970711951313, 0.29744417462950146, 0.19835441454182887, 0.09934122243585623]
# # 9 	Пример:  A skier is in a soccer ball high in the ocean .                                                       	Оценка:  [0.5619514869490163, 0.44432257867347535, 0.2680165156355778, 0.12638782754962138]
# # 10 	Пример:  A pair of meat and sheep are sitting together and wearing a suit .                                    	Оценка:  [0.5758289219624358, 0.3327475090445512, 0.12133158735615288, 0.06704325740058405]
# # 11 	Пример:  A man sitting at girls next to each other next to each other .                                        	Оценка:  [0.533113989983183, 0.4799049519403644, 0.42461633178803443, 0.3605766584996779]
# # 12 	Пример:  A woman laying on girl eats fun while children being now .                                            	Оценка:  [0.3402785236893603, 0.2343197292238376, 0.16586105071157164, 0.08609373184361885]
# # 13 	Пример:  The older flag is prepared to be the plane at the park .                                              	Оценка:  [0.4893604849295929, 0.34174500988297, 0.22012248449054683, 0.1079711005739161]
# # 14 	Пример:  The room is bottle , sink , and small drinking from pens and glasses .                                	Оценка:  [0.5758289219624358, 0.38090081277744137, 0.23877931071514819, 0.11523206875414535]
# # 15 	Пример:  A man skateboards down a graze eating some big ripe jelly .                                           	Оценка:  [0.3402785236893603, 0.08632412632135038, 0.0441049072731168, 0.029837713127693215]
# # 16 	Пример:  Green black and grey cat taking a nap with a two television .                                         	Оценка:  [0.5231483637805969, 0.39325936742827655, 0.24456656109396324, 0.11746099218395799]
# # 17 	Пример:  A bowl full of what looks like Two big fruits .                                                       	Оценка:  [0.41675437673324534, 0.3070457069283656, 0.20313747122261766, 0.1012530319921446]
# # 18 	Пример:  A hand , baseball on a angry area with a view behind him .                                            	Оценка:  [0.4893604849295929, 0.34174500988297, 0.12378396963260613, 0.06812515889872198]
# # 19 	Пример:  A large purple umbrella standing on a piece of bag .                                                  	Оценка:  [0.45014617508912413, 0.32323518297936166, 0.2111187176080899, 0.10442329545559932]
# # 20 	Пример:  Two people at a market pose for an clocks close to finish in the air .                                	Оценка:  [0.6282808624375432, 0.4443225786734753, 0.3187271473320672, 0.14518148959789903]
# # 21 	Пример:  the dish who is decorated with strawberries , mushrooms , chocolate and knife .                       	Оценка:  [0.4530597729822598, 0.225084799456331, 0.09049975320972704, 0.05302661682525778]
# # 22 	Пример:  A boy wearing a helmet holding a large kite in it .                                                   	Оценка:  [0.533113989983183, 0.36182311050064736, 0.12919925124488807, 0.07049916949671992]
# # 23 	Пример:  A couple of elephants standing next to each other .                                                   	Оценка:  [0.42919753763947605, 0.37125357768697886, 0.30826276460621843, 0.2573468506325473]
# # 24 	Пример:  A man and serving on a man playing baseball with his bat with an extended .                           	Оценка:  [0.5803810000880093, 0.38290559082342246, 0.13480517058692587, 0.07293588276546237]
# # 25 	Пример:  Someone wearing plaid sweater ready to hit the tennis tricycle .                                      	Оценка:  [0.1538967528127731, 0.05086223840955505, 0.029660903203497246, 0.021723184998105653]
# # 26 	Пример:  A bowl filled with berries and cantaloupe are lined up by on a table .                                	Оценка:  [0.6069769786668839, 0.5232669734616001, 0.3987590721833036, 0.17367786227241042]
# # 27 	Пример:  The people are on skis posing for a soccer ball .                                                     	Оценка:  [0.5104177855340404, 0.4167251379930962, 0.2554318471365747, 0.12161749074046846]
# # 28 	Пример:  A man Various hot dogs stand in a piece of pizza sitting .                                            	Оценка:  [0.4530597729822598, 0.3246284552986226, 0.2118008548235711, 0.10469312669112453]
# # 29 	Пример:  A women who is sitting in a chair and two workers looking in a computer .                             	Оценка:  [0.7398435111918139, 0.5970835291097519, 0.4402449689810936, 0.29794186008488804]
# # 30 	Пример:  A woman that is on her skis while a vehicle from their way to other vehicles .                        	Оценка:  [0.7626132357679226, 0.5446306254550225, 0.31222258402876674, 0.14280632873431442]
# # 31 	Пример:  A full view of red , and a sandwich cut pieces .                                                      	Оценка:  [0.5026246899500345, 0.347892817097899, 0.22308576866161578, 0.10913234729182814]
# # 32 	Пример:  A giraffe standing to some rocks in the middle of a grassy field .                                    	Оценка:  [0.6649099662043687, 0.5813634471819698, 0.4315229271655712, 0.29321021982166245]
# # 33 	Пример:  A girl sitting on a picnic man watching guitar and holding a Wii controller .                         	Оценка:  [0.5428967140306369, 0.43422081861268574, 0.31327681146619374, 0.22694394676932841]
# # 34 	Пример:  A cop sitting with a cross frowning and a donut cluttered toilet .                                    	Оценка:  [0.4893604849295929, 0.2369527555554263, 0.0940554774384672, 0.05468689644952395]
# # 35 	Пример:  A dog is sitting in a garage next to a cup of soda .                                                  	Оценка:  [0.6366028258614133, 0.5647438827324667, 0.4797543511401896, 0.36660395036046545]
# # 36 	Пример:  A large body of black t - up - - story dog beside a car .                                             	Оценка:  [0.6282808624375432, 0.40369385378392525, 0.24941747177008258, 0.11932116956929131]
# # 37 	Пример:  A counter with a chocolate sandwich on a plate with red whipped .                                     	Оценка:  [0.5026246899500345, 0.3829055908234224, 0.28507822708363717, 0.13278445727890759]
# # 38 	Пример:  A couple of birds sitting across on top of a beach near them .                                        	Оценка:  [0.6069769786668839, 0.4677501973766062, 0.2785468517364889, 0.13034506916523114]
# # 39 	Пример:  A woman eating a piece pizza with various pieces of cake .                                            	Оценка:  [0.5026246899500345, 0.2412154070004315, 0.0953216502610246, 0.055275062900335764]
# # 40 	Пример:  A person that is holding a young boy standing in a green field .                                      	Оценка:  [0.6920602346769048, 0.6639509405734763, 0.5122768853495414, 0.2122168245237715]
# # 41 	Пример:  Four skiers stand in grassy area with their boards in the background .                                	Оценка:  [0.5548826333938605, 0.4090062242255915, 0.2995316414137092, 0.13814340887248766]
# # 42 	Пример:  The man is in front of a red shaped cake .                                                            	Оценка:  [0.4812265031857878, 0.42578720527948616, 0.3416351427096076, 0.2794036231048865]
# # 43 	Пример:  A tray is well with a circle of meat large dough on a paper plate .                                   	Оценка:  [0.5026246899500346, 0.1119622739628565, 0.053603303127115566, 0.03487620690357151]
# # 44 	Пример:  A woman is on to play a ball in a match .                                                             	Оценка:  [0.45014617508912413, 0.32323518297936166, 0.2111187176080899, 0.10442329545559932]
# # 45 	Пример:  A beautiful woman standing next to a couch in front of each other .                                   	Оценка:  [0.6649099662043687, 0.5560541333192193, 0.4173552570984386, 0.2854833038569153]
# # 46 	Пример:  A male on a skateboard is near a skateboard in the air .                                              	Оценка:  [0.5548826333938605, 0.4681952501639962, 0.36684984164094486, 0.29578263349243455]
# # 47 	Пример:  A seed bench topped with food in front of them .                                                      	Оценка:  [0.42919753763947605, 0.3131273945313386, 0.24515235346013312, 0.18651976384997176]
# # 48 	Пример:  A giraffe standing in a grassy area with horns .                                                      	Оценка:  [0.42919753763947605, 0.39451579566877026, 0.3665882729601239, 0.3395712052221365]
# # 49 	Пример:  A group of people float in jackets in a field , and looks in a doorway .                              	Оценка:  [0.6805570473787206, 0.536458262707534, 0.367110852009989, 0.16256003406866554]

# %% [markdown]
# Оценка качества генерации текста после обучения с помощью MLE

# %%
# %%time
print("Оценка качества генерации текста на основе BLEU, после обучения с помощью MLE")
# проверка качества обучения
BLEU(data_file_test.tolist(), gen.sample(500, degree=degree).cpu().detach().numpy().tolist(), print_iteration=100)
# Out:
# Оценка качества генерации текста на основе BLEU, после обучения с помощью MLE
# --- --- ---
# Start BLEU
# 2 100 0.5297461279630729
# 2 200 0.5355221356420088
# 2 300 0.5266944489877361
# 2 400 0.5225363400622878
# 2 500 0.5234044964177561
# --- --- ---
# 2 -gram BLEU score :  0.5234044964177561
#
# 3 100 0.3926205639252202
# 3 200 0.3957693278204802
# 3 300 0.38304084088080326
# 3 400 0.3821505535401551
# 3 500 0.38369548201661996
# --- --- ---
# 3 -gram BLEU score :  0.38369548201661996
#
# 4 100 0.25846203230599557
# 4 200 0.2598156251690873
# 4 300 0.2497098871280157
# 4 400 0.24866964006164907
# 4 500 0.24843516011889202
# --- --- ---
# 4 -gram BLEU score :  0.24843516011889202
#
# 5 100 0.1546238787311136
# 5 200 0.15696177542613282
# 5 300 0.1508937330373346
# 5 400 0.1498088051055619
# 5 500 0.14932465150034782
# --- --- ---
# 5 -gram BLEU score :  0.14932465150034782
#
# CPU times: user 8min, sys: 175 ms, total: 8min
# Wall time: 8min

# %% [markdown]
# Оценка с возведением в степень

# %%
# примеры сгенерированных текстов
print("Примеры генерируемых текстов на основе MLE")
degree = 1.5
print("Degree:", degree)
samples = gen.sample(50, degree=degree).cpu().detach().numpy()

output_function = []
for i, samp in enumerate(samples):
  line = [word[x] for x in samp]
  line = ' '.join(line)
  output_function.append(line)
  bleu = BLEU(data_file_test.tolist(), [samp], flag_print=False)
  print("#", i, "\tПример: ", line, ' '*(100-len(line)), '\tОценка: ', bleu)
# Out:
# Примеры генерируемых текстов на основе MLE
# Degree: 1.5
# # 0 	Пример:  The man is doing the trick on a court near a man .                                                    	Оценка:  [0.5548826333938605, 0.37160681631842096, 0.13181065657459776, 0.07163684030886805]
# # 1 	Пример:  A man holding up a donut in a bowl of flowers in a room .                                             	Оценка:  [0.716350399411379, 0.6109741448719966, 0.404727200247809, 0.17575428316242378]
# # 2 	Пример:  A woman in a dress eating a pizza with a slice missing .                                              	Оценка:  [0.5548826333938605, 0.4090062242255915, 0.2518750835198491, 0.12026082240959093]
# # 3 	Пример:  A green train down train station on the tracks near a mountain .                                      	Оценка:  [0.5231483637805969, 0.3572998474390311, 0.22759483012793272, 0.11089345578518284]
# # 4 	Пример:  A lady is holding a tennis racket on a clay court .                                                   	Оценка:  [0.45014617508912413, 0.2823719413662334, 0.10727633416507679, 0.06075459680224768]
# # 5 	Пример:  A young man walking on a snow covered slope and a ball .                                              	Оценка:  [0.6134458325505882, 0.5005841126806674, 0.4144866661186027, 0.17913665263472914]
# # 6 	Пример:  People wearing snow gear on a big blue sky .                                                          	Оценка:  [0.3627381250550058, 0.19407576238520263, 0.08097785064266204, 0.048514214015354815]
# # 7 	Пример:  A man standing in the snow on a snow board in the ocean .                                             	Оценка:  [0.6920602346769048, 0.5970835291097519, 0.47307400630367114, 0.3155871214483429]
# # 8 	Пример:  The shaggy man on the kitchen counter with two pillows .                                              	Оценка:  [0.39735970711951313, 0.3273796750780409, 0.21314568971111159, 0.10522459120299207]
# # 9 	Пример:  A man sitting on a bed in a room next to a laptop computer .                                          	Оценка:  [0.7433919416750281, 0.7362673044371594, 0.6960884152052168, 0.5671781954589323]
# # 10 	Пример:  A cat is curled up on a bed in front of a television .                                                	Оценка:  [0.6920602346769048, 0.6639509405734763, 0.5669275668967321, 0.4812935724427397]
# # 11 	Пример:  The surfer is riding a skateboard down a hill in the air on a ramp .                                  	Оценка:  [0.7108186533109109, 0.6321632020469774, 0.4152094006260531, 0.28430843556982]
# # 12 	Пример:  A man is performing a trick on a wave in the ocean .                                                  	Оценка:  [0.5548826333938605, 0.4090062242255915, 0.2518750835198491, 0.12026082240959093]
# # 13 	Пример:  A man with his arms up in the air on his board .                                                      	Оценка:  [0.6134458325505882, 0.5509641073413446, 0.47094777718650466, 0.391722444087928]
# # 14 	Пример:  A man sitting on top of a couch with a plane in his hand .                                            	Оценка:  [0.7433919416750281, 0.6963890912495402, 0.5875766810867469, 0.46757566031593883]
# # 15 	Пример:  A man folding a baseball mitt with a bat on a court up .                                              	Оценка:  [0.4893604849295929, 0.10998372642798453, 0.052891281824158635, 0.03450509896165494]
# # 16 	Пример:  A man in a blue jacket and a woman holding a tennis racquet .                                         	Оценка:  [0.6366028258614133, 0.5647438827324667, 0.45372365197359754, 0.3052172947188026]
# # 17 	Пример:  A man standing with his arms up to hit a tennis ball .                                                	Оценка:  [0.6134458325505882, 0.5005841126806674, 0.34854035170959624, 0.15594751385814556]
# # 18 	Пример:  A man is sitting on a couch with her face and a woman a motorcycle .                                  	Оценка:  [0.7398435111918139, 0.624260333551995, 0.5171953073984757, 0.4222055277665569]
# # 19 	Пример:  A man is on the beach over the ocean with a surfboard .                                               	Оценка:  [0.6134458325505882, 0.5509641073413446, 0.47094777718650466, 0.314451886543678]
# # 20 	Пример:  A man sitting in a chair at a table eating a cake .                                                   	Оценка:  [0.6407232755171874, 0.5898890511424149, 0.5188040214030465, 0.4232558032555616]
# # 21 	Пример:  A cat is sitting on a computer desk next to a laptop computer .                                       	Оценка:  [0.6920602346769048, 0.6639509405734763, 0.589202081622577, 0.4321091081416893]
# # 22 	Пример:  A man eating a piece of pizza on a plate .                                                            	Оценка:  [0.5104177855340404, 0.4167251379930962, 0.30376137001310205, 0.13970181155244327]
# # 23 	Пример:  A man and a woman standing next to each other .                                                       	Оценка:  [0.5380275868489703, 0.5250407733778476, 0.4754122362294423, 0.39469037777958105]
# # 24 	Пример:  A man in a white shirt holding a tennis racket .                                                      	Оценка:  [0.42919753763947605, 0.3446412921261351, 0.22152015777624515, 0.10851920540253215]
# # 25 	Пример:  A person lying in a bed next to a wall and a window .                                                 	Оценка:  [0.6366028258614133, 0.5873573073196627, 0.4940911248125205, 0.32675455150630617]
# # 26 	Пример:  A woman with a pink surf board sitting in the middle of a tennis court .                              	Оценка:  [0.7108186533109109, 0.5813634471819698, 0.4637015624246032, 0.3567572848363358]
# # 27 	Пример:  A man holding a tennis racket and a tennis ball with a racket .                                       	Оценка:  [0.45014617508912413, 0.32323518297936166, 0.2111187176080899, 0.10442329545559932]
# # 28 	Пример:  A girl is sitting on a couch with her phone .                                                         	Оценка:  [0.5380275868489703, 0.45866536281292586, 0.388172465412544, 0.26939887898890685]
# # 29 	Пример:  A man is eating a piece of pizza with a pizza on it .                                                 	Оценка:  [0.6134458325505882, 0.43730050179518515, 0.14892676349028391, 0.07898674271716548]
# # 30 	Пример:  A young girl is holding a baseball bat while standing next to a woman and a giraffe .                 	Оценка:  [0.8429272304235246, 0.7572398297980701, 0.5653636138834072, 0.41806545797669464]
# # 31 	Пример:  Man about to hit a soccer ball on a court .                                                           	Оценка:  [0.45014617508912413, 0.2823719413662334, 0.10727633416507679, 0.06075459680224768]
# # 32 	Пример:  A man riding a skateboard in the air with a surfboard in the water .                                  	Оценка:  [0.7433919416750281, 0.716882776507279, 0.6240916750384193, 0.4524605448441326]
# # 33 	Пример:  A man holding a Wii remote to his face from his face .                                                	Оценка:  [0.45014617508912413, 0.3557663528269982, 0.22686182598679874, 0.11060764410745492]
# # 34 	Пример:  A man holding a tennis racquet in a field with his surfboard in the water .                           	Оценка:  [0.7398435111918139, 0.624260333551995, 0.45518966025586544, 0.19307672079928953]
# # 35 	Пример:  A little boy standing on top of a baseball field .                                                    	Оценка:  [0.5380275868489703, 0.45866536281292586, 0.3264128346656048, 0.2345253458551372]
# # 36 	Пример:  A little girl standing in a bathroom with a green toothbrush .                                        	Оценка:  [0.5619514869490163, 0.5196828406118894, 0.4507482544534971, 0.348762069035715]
# # 37 	Пример:  A man standing in a field with other boards in the water .                                            	Оценка:  [0.6134458325505882, 0.5269782107608059, 0.45548571872797966, 0.38139945326989394]
# # 38 	Пример:  A man in a wet suit standing in front of a large pizza .                                              	Оценка:  [0.6366028258614133, 0.5647438827324667, 0.5021277621795815, 0.43675651176119695]
# # 39 	Пример:  A man with a tennis racket is running to hit the ball .                                               	Оценка:  [0.435285750066007, 0.2761227119166927, 0.18759202316167214, 0.09500522640872923]
# # 40 	Пример:  A brown bear laying with a wooden seat and a white toothbrush .                                       	Оценка:  [0.5231483637805969, 0.4236258116837369, 0.3403336518440549, 0.2785517669300084]
# # 41 	Пример:  A man with a surf board in a park and there is a ball up to of the net .                              	Оценка:  [0.8944271909999159, 0.7084390461217407, 0.4522432940641193, 0.19207626942331976]
# # 42 	Пример:  A group of young men standing in the top of a living room .                                           	Оценка:  [0.6920602346769048, 0.6639509405734763, 0.5416668574934416, 0.22190230544737718]
# # 43 	Пример:  A man on a high surfboard in a park .                                                                 	Оценка:  [0.42919753763947605, 0.3446412921261351, 0.2634333477440361, 0.12465583273147404]
# # 44 	Пример:  A man is standing in front of a wooden floor in a room .                                              	Оценка:  [0.6920602346769048, 0.6639509405734763, 0.589202081622577, 0.4963630217015944]
# # 45 	Пример:  A man is standing in a living room with a laptop .                                                    	Оценка:  [0.5893796917545019, 0.5778821454656745, 0.5309354663044072, 0.45668988354930307]
# # 46 	Пример:  A man is standing on a beach with tennis rackets .                                                    	Оценка:  [0.42919753763947605, 0.39451579566877026, 0.32263864160302524, 0.26690401508436334]
# # 47 	Пример:  A man in a blue shirt carrying a surfboard while standing in the ocean .                              	Оценка:  [0.6882472016116853, 0.6187088159078515, 0.4858671038559722, 0.20341829039890905]
# # 48 	Пример:  A white bed with a floral pattern sign mounted on it .                                                	Оценка:  [0.39735970711951313, 0.2598414203059447, 0.10079037376973914, 0.05779779204056156]
# # 49 	Пример:  The two men are playing a game of soccer ball .                                                       	Оценка:  [0.45014617508912413, 0.32323518297936166, 0.2111187176080899, 0.10442329545559932]

# %%
# %%time
print("Оценка качества генерации текста на основе BLEU, после обучения с помощью MLE")
# проверка качества обучения
BLEU(data_file_test.tolist(), gen.sample(500, degree=degree).cpu().detach().numpy().tolist(), print_iteration=100)
# Out:
# Оценка качества генерации текста на основе BLEU, после обучения с помощью MLE
# --- --- ---
# Start BLEU
# 2 100 0.563796489069254
# 2 200 0.5639550303900202
# 2 300 0.5637841267854927
# 2 400 0.5605215308862388
# 2 500 0.5601664492111114
# --- --- ---
# 2 -gram BLEU score :  0.5601664492111114
#
# 3 100 0.47213855104687286
# 3 200 0.47811324904365854
# 3 300 0.4774650667857076
# 3 400 0.4719277409628813
# 3 500 0.47195595945252516
# --- --- ---
# 3 -gram BLEU score :  0.47195595945252516
#
# 4 100 0.3701483948064162
# 4 200 0.3755901049715418
# 4 300 0.37449450546496804
# 4 400 0.3669356998589144
# 4 500 0.3652760221418803
# --- --- ---
# 4 -gram BLEU score :  0.3652760221418803
#
# 5 100 0.26310827987968355
# 5 200 0.2629093684592063
# 5 300 0.263469259148831
# 5 400 0.2551864176682963
# 5 500 0.2528469331763989
# --- --- ---
# 5 -gram BLEU score :  0.2528469331763989
#
# CPU times: user 7min 40s, sys: 170 ms, total: 7min 40s
# Wall time: 7min 40s

# %% [markdown]
# Предварительное обучение дискриминатора

# %%
# %%time
# предобучение дискриминатора
print('Запуск обучения дискриминатора...')
# dis_optimizer = optim.Adagrad(dis.parameters()) # , lr=0.0001
# dis_optimizer = optim.Adam(gen.parameters(), lr=0.001, weight_decay=1e-5)#0.001
# dis_optimizer = optim.Adadelta(gen.parameters())
# dis_optimizer = optim.Adagrad(dis.parameters())#, lr=0.0001)#, weight_decay=1e-5)
#, weight_decay=1e-5) # регуляризация
train_discriminator(dis, dis_optimizer, data_file_tensor_train, gen, DIS_TRAIN_ITERATIONS, DIS_TRAIN_EPOCHS)#25, 1 | (15, 3), (25, 1)

# сохранение результата обучения
save_models(data_file_tensor_train, gen, dis, gen_optimizer, dis_optimizer,
            FILE_PATHS['saved_models'] + r'/' + r'seqgan_pretraining_dis.pytorch')

# ДО ОБУЧЕНИЯ: val_acc = 0.5230
# d-step 50 epoch 1 : .......... average_loss = 0.2859, train_acc = 0.9136, val_acc = 0.5240
# Out:
# Запуск обучения дискриминатора...
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 1 epoch 1 : .......... average_loss = 0.4372, train_acc = 0.8496, val_acc = 0.5000
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.3523, train_acc = 0.8874, val_acc = 0.5000
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.3495, train_acc = 0.8867, val_acc = 0.5000
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.3427, train_acc = 0.8874, val_acc = 0.5000
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.3434, train_acc = 0.8885, val_acc = 0.5000
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 6 epoch 1 : .......... average_loss = 0.3310, train_acc = 0.8898, val_acc = 0.5000
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 7 epoch 1 : .......... average_loss = 0.3262, train_acc = 0.8888, val_acc = 0.5000
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 8 epoch 1 : .......... average_loss = 0.3274, train_acc = 0.8879, val_acc = 0.5000
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 9 epoch 1 : .......... average_loss = 0.3222, train_acc = 0.8906, val_acc = 0.5000
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 10 epoch 1 : .......... average_loss = 0.3235, train_acc = 0.8895, val_acc = 0.5000
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 11 epoch 1 : .......... average_loss = 0.3129, train_acc = 0.8928, val_acc = 0.5000
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 12 epoch 1 : .......... average_loss = 0.3225, train_acc = 0.8883, val_acc = 0.5000
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 13 epoch 1 : .......... average_loss = 0.3198, train_acc = 0.8894, val_acc = 0.5000
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 14 epoch 1 : .......... average_loss = 0.3166, train_acc = 0.8907, val_acc = 0.5000
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 15 epoch 1 : .......... average_loss = 0.3204, train_acc = 0.8890, val_acc = 0.5000
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 16 epoch 1 : .......... average_loss = 0.3254, train_acc = 0.8859, val_acc = 0.5020
# ДО ОБУЧЕНИЯ: val_acc = 0.5020
# d-step 17 epoch 1 : .......... average_loss = 0.3205, train_acc = 0.8865, val_acc = 0.5010
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 18 epoch 1 : .......... average_loss = 0.3161, train_acc = 0.8883, val_acc = 0.5010
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 19 epoch 1 : .......... average_loss = 0.3187, train_acc = 0.8878, val_acc = 0.5020
# ДО ОБУЧЕНИЯ: val_acc = 0.5020
# d-step 20 epoch 1 : .......... average_loss = 0.3118, train_acc = 0.8899, val_acc = 0.5000
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 21 epoch 1 : .......... average_loss = 0.3068, train_acc = 0.8908, val_acc = 0.5000
# ДО ОБУЧЕНИЯ: val_acc = 0.5000
# d-step 22 epoch 1 : .......... average_loss = 0.3104, train_acc = 0.8887, val_acc = 0.5010
# ДО ОБУЧЕНИЯ: val_acc = 0.5010
# d-step 23 epoch 1 : .......... average_loss = 0.3085, train_acc = 0.8919, val_acc = 0.5010
# ДО ОБУЧЕНИЯ: val_acc = 0.5010
# d-step 24 epoch 1 : .......... average_loss = 0.3088, train_acc = 0.8898, val_acc = 0.5010
# ДО ОБУЧЕНИЯ: val_acc = 0.5010
# d-step 25 epoch 1 : .......... average_loss = 0.3056, train_acc = 0.8900, val_acc = 0.5010
# ДО ОБУЧЕНИЯ: val_acc = 0.5010
# d-step 26 epoch 1 : .......... average_loss = 0.3040, train_acc = 0.8898, val_acc = 0.5010
# ДО ОБУЧЕНИЯ: val_acc = 0.5010
# d-step 27 epoch 1 : .......... average_loss = 0.2956, train_acc = 0.8937, val_acc = 0.5010
# ДО ОБУЧЕНИЯ: val_acc = 0.5010
# d-step 28 epoch 1 : .......... average_loss = 0.3029, train_acc = 0.8898, val_acc = 0.5240
# ДО ОБУЧЕНИЯ: val_acc = 0.5240
# d-step 29 epoch 1 : .......... average_loss = 0.2993, train_acc = 0.8924, val_acc = 0.5510
# ДО ОБУЧЕНИЯ: val_acc = 0.5540
# d-step 30 epoch 1 : .......... average_loss = 0.3046, train_acc = 0.8914, val_acc = 0.5220
# ДО ОБУЧЕНИЯ: val_acc = 0.5230
# d-step 31 epoch 1 : .......... average_loss = 0.3058, train_acc = 0.8910, val_acc = 0.5140
# ДО ОБУЧЕНИЯ: val_acc = 0.5090
# d-step 32 epoch 1 : .......... average_loss = 0.2991, train_acc = 0.8918, val_acc = 0.5730
# ДО ОБУЧЕНИЯ: val_acc = 0.5760
# d-step 33 epoch 1 : .......... average_loss = 0.2876, train_acc = 0.8995, val_acc = 0.5520
# ДО ОБУЧЕНИЯ: val_acc = 0.5530
# d-step 34 epoch 1 : .......... average_loss = 0.2963, train_acc = 0.8939, val_acc = 0.5990
# ДО ОБУЧЕНИЯ: val_acc = 0.6040
# d-step 35 epoch 1 : .......... average_loss = 0.2915, train_acc = 0.8950, val_acc = 0.6080
# ДО ОБУЧЕНИЯ: val_acc = 0.6050
# d-step 36 epoch 1 : .......... average_loss = 0.2825, train_acc = 0.9002, val_acc = 0.5320
# ДО ОБУЧЕНИЯ: val_acc = 0.5290
# d-step 37 epoch 1 : .......... average_loss = 0.3051, train_acc = 0.8927, val_acc = 0.5600
# ДО ОБУЧЕНИЯ: val_acc = 0.5620
# d-step 38 epoch 1 : .......... average_loss = 0.3040, train_acc = 0.8930, val_acc = 0.5530
# ДО ОБУЧЕНИЯ: val_acc = 0.5530
# d-step 39 epoch 1 : .......... average_loss = 0.3033, train_acc = 0.8914, val_acc = 0.5650
# ДО ОБУЧЕНИЯ: val_acc = 0.5620
# d-step 40 epoch 1 : .......... average_loss = 0.2921, train_acc = 0.8960, val_acc = 0.5640
# ДО ОБУЧЕНИЯ: val_acc = 0.5670
# d-step 41 epoch 1 : .......... average_loss = 0.2995, train_acc = 0.8948, val_acc = 0.5460
# ДО ОБУЧЕНИЯ: val_acc = 0.5460
# d-step 42 epoch 1 : .......... average_loss = 0.2963, train_acc = 0.8975, val_acc = 0.5690
# ДО ОБУЧЕНИЯ: val_acc = 0.5740
# d-step 43 epoch 1 : .......... average_loss = 0.2910, train_acc = 0.8978, val_acc = 0.5380
# ДО ОБУЧЕНИЯ: val_acc = 0.5390
# d-step 44 epoch 1 : .......... average_loss = 0.2966, train_acc = 0.8948, val_acc = 0.5770
# ДО ОБУЧЕНИЯ: val_acc = 0.5790
# d-step 45 epoch 1 : .......... average_loss = 0.2854, train_acc = 0.9001, val_acc = 0.5660
# ДО ОБУЧЕНИЯ: val_acc = 0.5640
# d-step 46 epoch 1 : .......... average_loss = 0.2972, train_acc = 0.8942, val_acc = 0.5640
# ДО ОБУЧЕНИЯ: val_acc = 0.5630
# d-step 47 epoch 1 : .......... average_loss = 0.2803, train_acc = 0.9016, val_acc = 0.5750
# ДО ОБУЧЕНИЯ: val_acc = 0.5780
# d-step 48 epoch 1 : .......... average_loss = 0.2827, train_acc = 0.9012, val_acc = 0.6020
# ДО ОБУЧЕНИЯ: val_acc = 0.6060
# d-step 49 epoch 1 : .......... average_loss = 0.2826, train_acc = 0.9012, val_acc = 0.5820
# ДО ОБУЧЕНИЯ: val_acc = 0.5800
# d-step 50 epoch 1 : .......... average_loss = 0.2831, train_acc = 0.9002, val_acc = 0.5810
# ДО ОБУЧЕНИЯ: val_acc = 0.5730
# d-step 51 epoch 1 : .......... average_loss = 0.2855, train_acc = 0.8991, val_acc = 0.5870
# ДО ОБУЧЕНИЯ: val_acc = 0.5830
# d-step 52 epoch 1 : .......... average_loss = 0.2754, train_acc = 0.9040, val_acc = 0.5820
# ДО ОБУЧЕНИЯ: val_acc = 0.5880
# d-step 53 epoch 1 : .......... average_loss = 0.2757, train_acc = 0.9032, val_acc = 0.5990
# ДО ОБУЧЕНИЯ: val_acc = 0.5980
# d-step 54 epoch 1 : .......... average_loss = 0.2751, train_acc = 0.9044, val_acc = 0.5930
# ДО ОБУЧЕНИЯ: val_acc = 0.5880
# d-step 55 epoch 1 : .......... average_loss = 0.2765, train_acc = 0.9038, val_acc = 0.6070
# ДО ОБУЧЕНИЯ: val_acc = 0.6090
# d-step 56 epoch 1 : .......... average_loss = 0.2728, train_acc = 0.9040, val_acc = 0.6140
# ДО ОБУЧЕНИЯ: val_acc = 0.6200
# d-step 57 epoch 1 : .......... average_loss = 0.2772, train_acc = 0.9012, val_acc = 0.6330
# ДО ОБУЧЕНИЯ: val_acc = 0.6320
# d-step 58 epoch 1 : .......... average_loss = 0.2709, train_acc = 0.9073, val_acc = 0.5840
# ДО ОБУЧЕНИЯ: val_acc = 0.5860
# d-step 59 epoch 1 : .......... average_loss = 0.2723, train_acc = 0.9058, val_acc = 0.5680
# ДО ОБУЧЕНИЯ: val_acc = 0.5730
# d-step 60 epoch 1 : .......... average_loss = 0.2678, train_acc = 0.9061, val_acc = 0.6460
# ДО ОБУЧЕНИЯ: val_acc = 0.6460
# d-step 61 epoch 1 : .......... average_loss = 0.2601, train_acc = 0.9115, val_acc = 0.6210
# ДО ОБУЧЕНИЯ: val_acc = 0.6210
# d-step 62 epoch 1 : .......... average_loss = 0.2645, train_acc = 0.9085, val_acc = 0.6190
# ДО ОБУЧЕНИЯ: val_acc = 0.6220
# d-step 63 epoch 1 : .......... average_loss = 0.2594, train_acc = 0.9113, val_acc = 0.6350
# ДО ОБУЧЕНИЯ: val_acc = 0.6380
# d-step 64 epoch 1 : .......... average_loss = 0.2612, train_acc = 0.9101, val_acc = 0.6440
# ДО ОБУЧЕНИЯ: val_acc = 0.6460
# d-step 65 epoch 1 : .......... average_loss = 0.2658, train_acc = 0.9082, val_acc = 0.5580
# ДО ОБУЧЕНИЯ: val_acc = 0.5610
# d-step 66 epoch 1 : .......... average_loss = 0.2700, train_acc = 0.9074, val_acc = 0.6160
# ДО ОБУЧЕНИЯ: val_acc = 0.6180
# d-step 67 epoch 1 : .......... average_loss = 0.2661, train_acc = 0.9100, val_acc = 0.6360
# ДО ОБУЧЕНИЯ: val_acc = 0.6390
# d-step 68 epoch 1 : .......... average_loss = 0.2656, train_acc = 0.9073, val_acc = 0.6220
# ДО ОБУЧЕНИЯ: val_acc = 0.6190
# d-step 69 epoch 1 : .......... average_loss = 0.2591, train_acc = 0.9132, val_acc = 0.6460
# ДО ОБУЧЕНИЯ: val_acc = 0.6510
# d-step 70 epoch 1 : .......... average_loss = 0.2538, train_acc = 0.9142, val_acc = 0.6510
# ДО ОБУЧЕНИЯ: val_acc = 0.6490
# d-step 71 epoch 1 : .......... average_loss = 0.2577, train_acc = 0.9122, val_acc = 0.6770
# ДО ОБУЧЕНИЯ: val_acc = 0.6740
# d-step 72 epoch 1 : .......... average_loss = 0.2585, train_acc = 0.9128, val_acc = 0.6460
# ДО ОБУЧЕНИЯ: val_acc = 0.6510
# d-step 73 epoch 1 : .......... average_loss = 0.2505, train_acc = 0.9150, val_acc = 0.6350
# ДО ОБУЧЕНИЯ: val_acc = 0.6340
# d-step 74 epoch 1 : .......... average_loss = 0.2531, train_acc = 0.9135, val_acc = 0.6640
# ДО ОБУЧЕНИЯ: val_acc = 0.6550
# d-step 75 epoch 1 : .......... average_loss = 0.2633, train_acc = 0.9093, val_acc = 0.6260
# ДО ОБУЧЕНИЯ: val_acc = 0.6290
# d-step 76 epoch 1 : .......... average_loss = 0.2626, train_acc = 0.9104, val_acc = 0.6460
# ДО ОБУЧЕНИЯ: val_acc = 0.6430
# d-step 77 epoch 1 : .......... average_loss = 0.2471, train_acc = 0.9181, val_acc = 0.6270
# ДО ОБУЧЕНИЯ: val_acc = 0.6280
# d-step 78 epoch 1 : .......... average_loss = 0.2536, train_acc = 0.9163, val_acc = 0.6320
# ДО ОБУЧЕНИЯ: val_acc = 0.6290
# d-step 79 epoch 1 : .......... average_loss = 0.2538, train_acc = 0.9141, val_acc = 0.6430
# ДО ОБУЧЕНИЯ: val_acc = 0.6370
# d-step 80 epoch 1 : .......... average_loss = 0.2633, train_acc = 0.9095, val_acc = 0.6730
# ДО ОБУЧЕНИЯ: val_acc = 0.6780
# d-step 81 epoch 1 : .......... average_loss = 0.2506, train_acc = 0.9159, val_acc = 0.6400
# ДО ОБУЧЕНИЯ: val_acc = 0.6370
# d-step 82 epoch 1 : .......... average_loss = 0.2519, train_acc = 0.9146, val_acc = 0.6560
# ДО ОБУЧЕНИЯ: val_acc = 0.6450
# d-step 83 epoch 1 : .......... average_loss = 0.2481, train_acc = 0.9173, val_acc = 0.6540
# ДО ОБУЧЕНИЯ: val_acc = 0.6520
# d-step 84 epoch 1 : .......... average_loss = 0.2526, train_acc = 0.9141, val_acc = 0.6670
# ДО ОБУЧЕНИЯ: val_acc = 0.6710
# d-step 85 epoch 1 : .......... average_loss = 0.2523, train_acc = 0.9154, val_acc = 0.6320
# ДО ОБУЧЕНИЯ: val_acc = 0.6270
# d-step 86 epoch 1 : .......... average_loss = 0.2425, train_acc = 0.9162, val_acc = 0.6510
# ДО ОБУЧЕНИЯ: val_acc = 0.6540
# d-step 87 epoch 1 : .......... average_loss = 0.2402, train_acc = 0.9194, val_acc = 0.6400
# ДО ОБУЧЕНИЯ: val_acc = 0.6380
# d-step 88 epoch 1 : .......... average_loss = 0.2410, train_acc = 0.9204, val_acc = 0.6770
# ДО ОБУЧЕНИЯ: val_acc = 0.6860
# d-step 89 epoch 1 : .......... average_loss = 0.2470, train_acc = 0.9165, val_acc = 0.6560
# ДО ОБУЧЕНИЯ: val_acc = 0.6580
# d-step 90 epoch 1 : .......... average_loss = 0.2509, train_acc = 0.9155, val_acc = 0.6530
# ДО ОБУЧЕНИЯ: val_acc = 0.6630
# d-step 91 epoch 1 : .......... average_loss = 0.2483, train_acc = 0.9173, val_acc = 0.6350
# ДО ОБУЧЕНИЯ: val_acc = 0.6370
# d-step 92 epoch 1 : .......... average_loss = 0.2363, train_acc = 0.9226, val_acc = 0.6700
# ДО ОБУЧЕНИЯ: val_acc = 0.6740
# d-step 93 epoch 1 : .......... average_loss = 0.2442, train_acc = 0.9195, val_acc = 0.6870
# ДО ОБУЧЕНИЯ: val_acc = 0.6900
# d-step 94 epoch 1 : .......... average_loss = 0.2449, train_acc = 0.9181, val_acc = 0.6660
# ДО ОБУЧЕНИЯ: val_acc = 0.6630
# d-step 95 epoch 1 : .......... average_loss = 0.2403, train_acc = 0.9206, val_acc = 0.6630
# ДО ОБУЧЕНИЯ: val_acc = 0.6590
# d-step 96 epoch 1 : .......... average_loss = 0.2467, train_acc = 0.9187, val_acc = 0.6430
# ДО ОБУЧЕНИЯ: val_acc = 0.6440
# d-step 97 epoch 1 : .......... average_loss = 0.2366, train_acc = 0.9230, val_acc = 0.6570
# ДО ОБУЧЕНИЯ: val_acc = 0.6540
# d-step 98 epoch 1 : .......... average_loss = 0.2413, train_acc = 0.9205, val_acc = 0.6600
# ДО ОБУЧЕНИЯ: val_acc = 0.6670
# d-step 99 epoch 1 : .......... average_loss = 0.2388, train_acc = 0.9207, val_acc = 0.6580
# ДО ОБУЧЕНИЯ: val_acc = 0.6610
# d-step 100 epoch 1 : .......... average_loss = 0.2436, train_acc = 0.9189, val_acc = 0.6870
# ДО ОБУЧЕНИЯ: val_acc = 0.6840
# d-step 101 epoch 1 : .......... average_loss = 0.2320, train_acc = 0.9231, val_acc = 0.6800
# ДО ОБУЧЕНИЯ: val_acc = 0.6830
# d-step 102 epoch 1 : .......... average_loss = 0.2370, train_acc = 0.9215, val_acc = 0.6720
# ДО ОБУЧЕНИЯ: val_acc = 0.6710
# d-step 103 epoch 1 : .......... average_loss = 0.2362, train_acc = 0.9218, val_acc = 0.6580
# ДО ОБУЧЕНИЯ: val_acc = 0.6590
# d-step 104 epoch 1 : .......... average_loss = 0.2396, train_acc = 0.9226, val_acc = 0.6960
# ДО ОБУЧЕНИЯ: val_acc = 0.6930
# d-step 105 epoch 1 : .......... average_loss = 0.2280, train_acc = 0.9248, val_acc = 0.6800
# ДО ОБУЧЕНИЯ: val_acc = 0.6790
# d-step 106 epoch 1 : .......... average_loss = 0.2342, train_acc = 0.9224, val_acc = 0.7080
# ДО ОБУЧЕНИЯ: val_acc = 0.7090
# d-step 107 epoch 1 : .......... average_loss = 0.2296, train_acc = 0.9257, val_acc = 0.6870
# ДО ОБУЧЕНИЯ: val_acc = 0.6820
# d-step 108 epoch 1 : .......... average_loss = 0.2411, train_acc = 0.9195, val_acc = 0.6960
# ДО ОБУЧЕНИЯ: val_acc = 0.6960
# d-step 109 epoch 1 : .......... average_loss = 0.2359, train_acc = 0.9224, val_acc = 0.6800
# ДО ОБУЧЕНИЯ: val_acc = 0.6870
# d-step 110 epoch 1 : .......... average_loss = 0.2348, train_acc = 0.9234, val_acc = 0.7070
# ДО ОБУЧЕНИЯ: val_acc = 0.7050
# d-step 111 epoch 1 : .......... average_loss = 0.2357, train_acc = 0.9238, val_acc = 0.6630
# ДО ОБУЧЕНИЯ: val_acc = 0.6620
# d-step 112 epoch 1 : .......... average_loss = 0.2300, train_acc = 0.9254, val_acc = 0.6740
# ДО ОБУЧЕНИЯ: val_acc = 0.6720
# d-step 113 epoch 1 : .......... average_loss = 0.2342, train_acc = 0.9234, val_acc = 0.6720
# ДО ОБУЧЕНИЯ: val_acc = 0.6690
# d-step 114 epoch 1 : .......... average_loss = 0.2330, train_acc = 0.9228, val_acc = 0.7000
# ДО ОБУЧЕНИЯ: val_acc = 0.6960
# d-step 115 epoch 1 : .......... average_loss = 0.2325, train_acc = 0.9237, val_acc = 0.6400
# ДО ОБУЧЕНИЯ: val_acc = 0.6420
# d-step 116 epoch 1 : .......... average_loss = 0.2296, train_acc = 0.9261, val_acc = 0.7350
# ДО ОБУЧЕНИЯ: val_acc = 0.7300
# d-step 117 epoch 1 : .......... average_loss = 0.2284, train_acc = 0.9263, val_acc = 0.6880
# ДО ОБУЧЕНИЯ: val_acc = 0.6940
# d-step 118 epoch 1 : .......... average_loss = 0.2369, train_acc = 0.9234, val_acc = 0.6780
# ДО ОБУЧЕНИЯ: val_acc = 0.6760
# d-step 119 epoch 1 : .......... average_loss = 0.2261, train_acc = 0.9284, val_acc = 0.7090
# ДО ОБУЧЕНИЯ: val_acc = 0.7050
# d-step 120 epoch 1 : .......... average_loss = 0.2188, train_acc = 0.9298, val_acc = 0.6620
# ДО ОБУЧЕНИЯ: val_acc = 0.6650
# d-step 121 epoch 1 : .......... average_loss = 0.2290, train_acc = 0.9252, val_acc = 0.7070
# ДО ОБУЧЕНИЯ: val_acc = 0.7080
# d-step 122 epoch 1 : .......... average_loss = 0.2270, train_acc = 0.9274, val_acc = 0.7090
# ДО ОБУЧЕНИЯ: val_acc = 0.7160
# d-step 123 epoch 1 : .......... average_loss = 0.2280, train_acc = 0.9268, val_acc = 0.6880
# ДО ОБУЧЕНИЯ: val_acc = 0.6960
# d-step 124 epoch 1 : .......... average_loss = 0.2311, train_acc = 0.9244, val_acc = 0.7120
# ДО ОБУЧЕНИЯ: val_acc = 0.7120
# d-step 125 epoch 1 : .......... average_loss = 0.2258, train_acc = 0.9276, val_acc = 0.6990
# ДО ОБУЧЕНИЯ: val_acc = 0.6950
# d-step 126 epoch 1 : .......... average_loss = 0.2241, train_acc = 0.9282, val_acc = 0.7030
# ДО ОБУЧЕНИЯ: val_acc = 0.7100
# d-step 127 epoch 1 : .......... average_loss = 0.2275, train_acc = 0.9274, val_acc = 0.6670
# ДО ОБУЧЕНИЯ: val_acc = 0.6670
# d-step 128 epoch 1 : .......... average_loss = 0.2227, train_acc = 0.9288, val_acc = 0.6980
# ДО ОБУЧЕНИЯ: val_acc = 0.6910
# d-step 129 epoch 1 : .......... average_loss = 0.2228, train_acc = 0.9279, val_acc = 0.7140
# ДО ОБУЧЕНИЯ: val_acc = 0.7130
# d-step 130 epoch 1 : .......... average_loss = 0.2208, train_acc = 0.9287, val_acc = 0.7110
# ДО ОБУЧЕНИЯ: val_acc = 0.7090
# d-step 131 epoch 1 : .......... average_loss = 0.2192, train_acc = 0.9315, val_acc = 0.7140
# ДО ОБУЧЕНИЯ: val_acc = 0.7120
# d-step 132 epoch 1 : .......... average_loss = 0.2205, train_acc = 0.9295, val_acc = 0.7050
# ДО ОБУЧЕНИЯ: val_acc = 0.7140
# d-step 133 epoch 1 : .......... average_loss = 0.2199, train_acc = 0.9294, val_acc = 0.7230
# ДО ОБУЧЕНИЯ: val_acc = 0.7260
# d-step 134 epoch 1 : .......... average_loss = 0.2213, train_acc = 0.9280, val_acc = 0.7200
# ДО ОБУЧЕНИЯ: val_acc = 0.7270
# d-step 135 epoch 1 : .......... average_loss = 0.2106, train_acc = 0.9328, val_acc = 0.6790
# ДО ОБУЧЕНИЯ: val_acc = 0.6820
# d-step 136 epoch 1 : .......... average_loss = 0.2170, train_acc = 0.9306, val_acc = 0.7160
# ДО ОБУЧЕНИЯ: val_acc = 0.7080
# d-step 137 epoch 1 : .......... average_loss = 0.2219, train_acc = 0.9287, val_acc = 0.7190
# ДО ОБУЧЕНИЯ: val_acc = 0.7130
# d-step 138 epoch 1 : .......... average_loss = 0.2145, train_acc = 0.9336, val_acc = 0.7010
# ДО ОБУЧЕНИЯ: val_acc = 0.6980
# d-step 139 epoch 1 : .......... average_loss = 0.2137, train_acc = 0.9319, val_acc = 0.7280
# ДО ОБУЧЕНИЯ: val_acc = 0.7220
# d-step 140 epoch 1 : .......... average_loss = 0.2186, train_acc = 0.9290, val_acc = 0.7190
# ДО ОБУЧЕНИЯ: val_acc = 0.7100
# d-step 141 epoch 1 : .......... average_loss = 0.2227, train_acc = 0.9310, val_acc = 0.7250
# ДО ОБУЧЕНИЯ: val_acc = 0.7180
# d-step 142 epoch 1 : .......... average_loss = 0.2171, train_acc = 0.9314, val_acc = 0.7140
# ДО ОБУЧЕНИЯ: val_acc = 0.7190
# d-step 143 epoch 1 : .......... average_loss = 0.2141, train_acc = 0.9328, val_acc = 0.7320
# ДО ОБУЧЕНИЯ: val_acc = 0.7300
# d-step 144 epoch 1 : .......... average_loss = 0.2177, train_acc = 0.9313, val_acc = 0.7030
# ДО ОБУЧЕНИЯ: val_acc = 0.7090
# d-step 145 epoch 1 : .......... average_loss = 0.2112, train_acc = 0.9339, val_acc = 0.7220
# ДО ОБУЧЕНИЯ: val_acc = 0.7180
# d-step 146 epoch 1 : .......... average_loss = 0.2124, train_acc = 0.9331, val_acc = 0.7130
# ДО ОБУЧЕНИЯ: val_acc = 0.7180
# d-step 147 epoch 1 : .......... average_loss = 0.2144, train_acc = 0.9332, val_acc = 0.7380
# ДО ОБУЧЕНИЯ: val_acc = 0.7350
# d-step 148 epoch 1 : .......... average_loss = 0.2088, train_acc = 0.9345, val_acc = 0.7460
# ДО ОБУЧЕНИЯ: val_acc = 0.7440
# d-step 149 epoch 1 : .......... average_loss = 0.2164, train_acc = 0.9330, val_acc = 0.7100
# ДО ОБУЧЕНИЯ: val_acc = 0.7160
# d-step 150 epoch 1 : .......... average_loss = 0.2134, train_acc = 0.9324, val_acc = 0.7420
# ДО ОБУЧЕНИЯ: val_acc = 0.7470
# d-step 151 epoch 1 : .......... average_loss = 0.2091, train_acc = 0.9342, val_acc = 0.7260
# ДО ОБУЧЕНИЯ: val_acc = 0.7240
# d-step 152 epoch 1 : .......... average_loss = 0.2152, train_acc = 0.9325, val_acc = 0.7360
# ДО ОБУЧЕНИЯ: val_acc = 0.7330
# d-step 153 epoch 1 : .......... average_loss = 0.2058, train_acc = 0.9345, val_acc = 0.7300
# ДО ОБУЧЕНИЯ: val_acc = 0.7330
# d-step 154 epoch 1 : .......... average_loss = 0.2122, train_acc = 0.9341, val_acc = 0.7360
# ДО ОБУЧЕНИЯ: val_acc = 0.7290
# d-step 155 epoch 1 : .......... average_loss = 0.2132, train_acc = 0.9339, val_acc = 0.7260
# ДО ОБУЧЕНИЯ: val_acc = 0.7270
# d-step 156 epoch 1 : .......... average_loss = 0.2047, train_acc = 0.9357, val_acc = 0.7400
# ДО ОБУЧЕНИЯ: val_acc = 0.7350
# d-step 157 epoch 1 : .......... average_loss = 0.2026, train_acc = 0.9363, val_acc = 0.7520
# ДО ОБУЧЕНИЯ: val_acc = 0.7580
# d-step 158 epoch 1 : .......... average_loss = 0.2059, train_acc = 0.9349, val_acc = 0.6710
# ДО ОБУЧЕНИЯ: val_acc = 0.6740
# d-step 159 epoch 1 : .......... average_loss = 0.2143, train_acc = 0.9314, val_acc = 0.7520
# ДО ОБУЧЕНИЯ: val_acc = 0.7570
# d-step 160 epoch 1 : .......... average_loss = 0.2084, train_acc = 0.9343, val_acc = 0.7550
# ДО ОБУЧЕНИЯ: val_acc = 0.7550
# d-step 161 epoch 1 : .......... average_loss = 0.2041, train_acc = 0.9368, val_acc = 0.6990
# ДО ОБУЧЕНИЯ: val_acc = 0.7040
# d-step 162 epoch 1 : .......... average_loss = 0.2106, train_acc = 0.9358, val_acc = 0.6840
# ДО ОБУЧЕНИЯ: val_acc = 0.6830
# d-step 163 epoch 1 : .......... average_loss = 0.2074, train_acc = 0.9360, val_acc = 0.7420
# ДО ОБУЧЕНИЯ: val_acc = 0.7400
# d-step 164 epoch 1 : .......... average_loss = 0.2059, train_acc = 0.9369, val_acc = 0.7450
# ДО ОБУЧЕНИЯ: val_acc = 0.7430
# d-step 165 epoch 1 : .......... average_loss = 0.2043, train_acc = 0.9367, val_acc = 0.7110
# ДО ОБУЧЕНИЯ: val_acc = 0.7120
# d-step 166 epoch 1 : .......... average_loss = 0.2092, train_acc = 0.9346, val_acc = 0.7190
# ДО ОБУЧЕНИЯ: val_acc = 0.7170
# d-step 167 epoch 1 : .......... average_loss = 0.2031, train_acc = 0.9372, val_acc = 0.7630
# ДО ОБУЧЕНИЯ: val_acc = 0.7620
# d-step 168 epoch 1 : .......... average_loss = 0.2020, train_acc = 0.9361, val_acc = 0.7620
# ДО ОБУЧЕНИЯ: val_acc = 0.7570
# d-step 169 epoch 1 : .......... average_loss = 0.2024, train_acc = 0.9367, val_acc = 0.7610
# ДО ОБУЧЕНИЯ: val_acc = 0.7580
# d-step 170 epoch 1 : .......... average_loss = 0.1966, train_acc = 0.9411, val_acc = 0.7490
# ДО ОБУЧЕНИЯ: val_acc = 0.7580
# d-step 171 epoch 1 : .......... average_loss = 0.2035, train_acc = 0.9377, val_acc = 0.7530
# ДО ОБУЧЕНИЯ: val_acc = 0.7500
# d-step 172 epoch 1 : .......... average_loss = 0.2025, train_acc = 0.9374, val_acc = 0.7460
# ДО ОБУЧЕНИЯ: val_acc = 0.7520
# d-step 173 epoch 1 : .......... average_loss = 0.2009, train_acc = 0.9386, val_acc = 0.7330
# ДО ОБУЧЕНИЯ: val_acc = 0.7290
# d-step 174 epoch 1 : .......... average_loss = 0.2027, train_acc = 0.9368, val_acc = 0.7580
# ДО ОБУЧЕНИЯ: val_acc = 0.7570
# d-step 175 epoch 1 : .......... average_loss = 0.2005, train_acc = 0.9391, val_acc = 0.7440
# ДО ОБУЧЕНИЯ: val_acc = 0.7430
# d-step 176 epoch 1 : .......... average_loss = 0.2032, train_acc = 0.9374, val_acc = 0.7090
# ДО ОБУЧЕНИЯ: val_acc = 0.7100
# d-step 177 epoch 1 : .......... average_loss = 0.2017, train_acc = 0.9381, val_acc = 0.7500
# ДО ОБУЧЕНИЯ: val_acc = 0.7510
# d-step 178 epoch 1 : .......... average_loss = 0.1937, train_acc = 0.9411, val_acc = 0.7410
# ДО ОБУЧЕНИЯ: val_acc = 0.7470
# d-step 179 epoch 1 : .......... average_loss = 0.1969, train_acc = 0.9400, val_acc = 0.7260
# ДО ОБУЧЕНИЯ: val_acc = 0.7240
# d-step 180 epoch 1 : .......... average_loss = 0.1999, train_acc = 0.9391, val_acc = 0.7630
# ДО ОБУЧЕНИЯ: val_acc = 0.7590
# d-step 181 epoch 1 : .......... average_loss = 0.2026, train_acc = 0.9373, val_acc = 0.7460
# ДО ОБУЧЕНИЯ: val_acc = 0.7490
# d-step 182 epoch 1 : .......... average_loss = 0.1993, train_acc = 0.9384, val_acc = 0.7670
# ДО ОБУЧЕНИЯ: val_acc = 0.7650
# d-step 183 epoch 1 : .......... average_loss = 0.1987, train_acc = 0.9387, val_acc = 0.7660
# ДО ОБУЧЕНИЯ: val_acc = 0.7710
# d-step 184 epoch 1 : .......... average_loss = 0.2025, train_acc = 0.9395, val_acc = 0.7510
# ДО ОБУЧЕНИЯ: val_acc = 0.7460
# d-step 185 epoch 1 : .......... average_loss = 0.1943, train_acc = 0.9415, val_acc = 0.7330
# ДО ОБУЧЕНИЯ: val_acc = 0.7330
# d-step 186 epoch 1 : .......... average_loss = 0.1843, train_acc = 0.9456, val_acc = 0.7650
# ДО ОБУЧЕНИЯ: val_acc = 0.7620
# d-step 187 epoch 1 : .......... average_loss = 0.2002, train_acc = 0.9395, val_acc = 0.7710
# ДО ОБУЧЕНИЯ: val_acc = 0.7770
# d-step 188 epoch 1 : .......... average_loss = 0.1932, train_acc = 0.9409, val_acc = 0.7210
# ДО ОБУЧЕНИЯ: val_acc = 0.7240
# d-step 189 epoch 1 : .......... average_loss = 0.1969, train_acc = 0.9403, val_acc = 0.7570
# ДО ОБУЧЕНИЯ: val_acc = 0.7650
# d-step 190 epoch 1 : .......... average_loss = 0.1868, train_acc = 0.9434, val_acc = 0.7660
# ДО ОБУЧЕНИЯ: val_acc = 0.7590
# d-step 191 epoch 1 : .......... average_loss = 0.1935, train_acc = 0.9417, val_acc = 0.7430
# ДО ОБУЧЕНИЯ: val_acc = 0.7390
# d-step 192 epoch 1 : .......... average_loss = 0.1984, train_acc = 0.9383, val_acc = 0.7590
# ДО ОБУЧЕНИЯ: val_acc = 0.7640
# d-step 193 epoch 1 : .......... average_loss = 0.1906, train_acc = 0.9415, val_acc = 0.7640
# ДО ОБУЧЕНИЯ: val_acc = 0.7660
# d-step 194 epoch 1 : .......... average_loss = 0.1900, train_acc = 0.9432, val_acc = 0.7660
# ДО ОБУЧЕНИЯ: val_acc = 0.7680
# d-step 195 epoch 1 : .......... average_loss = 0.1941, train_acc = 0.9415, val_acc = 0.7770
# ДО ОБУЧЕНИЯ: val_acc = 0.7710
# d-step 196 epoch 1 : .......... average_loss = 0.1922, train_acc = 0.9427, val_acc = 0.7650
# ДО ОБУЧЕНИЯ: val_acc = 0.7700
# d-step 197 epoch 1 : .......... average_loss = 0.1975, train_acc = 0.9391, val_acc = 0.7570
# ДО ОБУЧЕНИЯ: val_acc = 0.7580
# d-step 198 epoch 1 : .......... average_loss = 0.1923, train_acc = 0.9419, val_acc = 0.7410
# ДО ОБУЧЕНИЯ: val_acc = 0.7350
# d-step 199 epoch 1 : .......... average_loss = 0.1981, train_acc = 0.9395, val_acc = 0.7410
# ДО ОБУЧЕНИЯ: val_acc = 0.7470
# d-step 200 epoch 1 : .......... average_loss = 0.1884, train_acc = 0.9415, val_acc = 0.7740
# ДО ОБУЧЕНИЯ: val_acc = 0.7820
# d-step 201 epoch 1 : .......... average_loss = 0.1914, train_acc = 0.9432, val_acc = 0.7640
# ДО ОБУЧЕНИЯ: val_acc = 0.7700
# d-step 202 epoch 1 : .......... average_loss = 0.1978, train_acc = 0.9398, val_acc = 0.7660
# ДО ОБУЧЕНИЯ: val_acc = 0.7550
# d-step 203 epoch 1 : .......... average_loss = 0.1854, train_acc = 0.9439, val_acc = 0.7730
# ДО ОБУЧЕНИЯ: val_acc = 0.7840
# d-step 204 epoch 1 : .......... average_loss = 0.1821, train_acc = 0.9463, val_acc = 0.7560
# ДО ОБУЧЕНИЯ: val_acc = 0.7600
# d-step 205 epoch 1 : .......... average_loss = 0.1891, train_acc = 0.9433, val_acc = 0.7750
# ДО ОБУЧЕНИЯ: val_acc = 0.7760
# d-step 206 epoch 1 : .......... average_loss = 0.1906, train_acc = 0.9433, val_acc = 0.7710
# ДО ОБУЧЕНИЯ: val_acc = 0.7750
# d-step 207 epoch 1 : .......... average_loss = 0.1998, train_acc = 0.9405, val_acc = 0.7710
# ДО ОБУЧЕНИЯ: val_acc = 0.7730
# d-step 208 epoch 1 : .......... average_loss = 0.1941, train_acc = 0.9422, val_acc = 0.7670
# ДО ОБУЧЕНИЯ: val_acc = 0.7660
# d-step 209 epoch 1 : .......... average_loss = 0.1868, train_acc = 0.9440, val_acc = 0.7340
# ДО ОБУЧЕНИЯ: val_acc = 0.7290
# d-step 210 epoch 1 : .......... average_loss = 0.2003, train_acc = 0.9395, val_acc = 0.7390
# ДО ОБУЧЕНИЯ: val_acc = 0.7410
# d-step 211 epoch 1 : .......... average_loss = 0.1878, train_acc = 0.9440, val_acc = 0.7840
# ДО ОБУЧЕНИЯ: val_acc = 0.7830
# d-step 212 epoch 1 : .......... average_loss = 0.1921, train_acc = 0.9416, val_acc = 0.7580
# ДО ОБУЧЕНИЯ: val_acc = 0.7530
# d-step 213 epoch 1 : .......... average_loss = 0.1866, train_acc = 0.9446, val_acc = 0.7600
# ДО ОБУЧЕНИЯ: val_acc = 0.7600
# d-step 214 epoch 1 : .......... average_loss = 0.1966, train_acc = 0.9392, val_acc = 0.7870
# ДО ОБУЧЕНИЯ: val_acc = 0.7830
# d-step 215 epoch 1 : .......... average_loss = 0.1854, train_acc = 0.9443, val_acc = 0.7760
# ДО ОБУЧЕНИЯ: val_acc = 0.7720
# d-step 216 epoch 1 : .......... average_loss = 0.1789, train_acc = 0.9477, val_acc = 0.7830
# ДО ОБУЧЕНИЯ: val_acc = 0.7790
# d-step 217 epoch 1 : .......... average_loss = 0.1949, train_acc = 0.9408, val_acc = 0.7580
# ДО ОБУЧЕНИЯ: val_acc = 0.7530
# d-step 218 epoch 1 : .......... average_loss = 0.1883, train_acc = 0.9425, val_acc = 0.7830
# ДО ОБУЧЕНИЯ: val_acc = 0.7820
# d-step 219 epoch 1 : .......... average_loss = 0.1786, train_acc = 0.9469, val_acc = 0.7770
# ДО ОБУЧЕНИЯ: val_acc = 0.7740
# d-step 220 epoch 1 : .......... average_loss = 0.1764, train_acc = 0.9472, val_acc = 0.7930
# ДО ОБУЧЕНИЯ: val_acc = 0.7890
# d-step 221 epoch 1 : .......... average_loss = 0.1854, train_acc = 0.9435, val_acc = 0.7800
# ДО ОБУЧЕНИЯ: val_acc = 0.7810
# d-step 222 epoch 1 : .......... average_loss = 0.1897, train_acc = 0.9440, val_acc = 0.7780
# ДО ОБУЧЕНИЯ: val_acc = 0.7860
# d-step 223 epoch 1 : .......... average_loss = 0.1737, train_acc = 0.9485, val_acc = 0.7780
# ДО ОБУЧЕНИЯ: val_acc = 0.7740
# d-step 224 epoch 1 : .......... average_loss = 0.1799, train_acc = 0.9473, val_acc = 0.7690
# ДО ОБУЧЕНИЯ: val_acc = 0.7750
# d-step 225 epoch 1 : .......... average_loss = 0.1795, train_acc = 0.9472, val_acc = 0.7820
# ДО ОБУЧЕНИЯ: val_acc = 0.7800
# d-step 226 epoch 1 : .......... average_loss = 0.1839, train_acc = 0.9451, val_acc = 0.7780
# ДО ОБУЧЕНИЯ: val_acc = 0.7770
# d-step 227 epoch 1 : .......... average_loss = 0.1845, train_acc = 0.9447, val_acc = 0.7910
# ДО ОБУЧЕНИЯ: val_acc = 0.7930
# d-step 228 epoch 1 : .......... average_loss = 0.1759, train_acc = 0.9488, val_acc = 0.7850
# ДО ОБУЧЕНИЯ: val_acc = 0.7830
# d-step 229 epoch 1 : .......... average_loss = 0.1778, train_acc = 0.9476, val_acc = 0.7780
# ДО ОБУЧЕНИЯ: val_acc = 0.7850
# d-step 230 epoch 1 : .......... average_loss = 0.1797, train_acc = 0.9473, val_acc = 0.7960
# ДО ОБУЧЕНИЯ: val_acc = 0.8000
# d-step 231 epoch 1 : .......... average_loss = 0.1833, train_acc = 0.9449, val_acc = 0.7340
# ДО ОБУЧЕНИЯ: val_acc = 0.7430
# d-step 232 epoch 1 : .......... average_loss = 0.1767, train_acc = 0.9468, val_acc = 0.7890
# ДО ОБУЧЕНИЯ: val_acc = 0.7900
# d-step 233 epoch 1 : .......... average_loss = 0.1820, train_acc = 0.9454, val_acc = 0.7880
# ДО ОБУЧЕНИЯ: val_acc = 0.7860
# d-step 234 epoch 1 : .......... average_loss = 0.1806, train_acc = 0.9477, val_acc = 0.7880
# ДО ОБУЧЕНИЯ: val_acc = 0.7910
# d-step 235 epoch 1 : .......... average_loss = 0.1757, train_acc = 0.9487, val_acc = 0.7930
# ДО ОБУЧЕНИЯ: val_acc = 0.7950
# d-step 236 epoch 1 : .......... average_loss = 0.1809, train_acc = 0.9459, val_acc = 0.7920
# ДО ОБУЧЕНИЯ: val_acc = 0.8050
# d-step 237 epoch 1 : .......... average_loss = 0.1780, train_acc = 0.9486, val_acc = 0.7540
# ДО ОБУЧЕНИЯ: val_acc = 0.7580
# d-step 238 epoch 1 : .......... average_loss = 0.1738, train_acc = 0.9488, val_acc = 0.7760
# ДО ОБУЧЕНИЯ: val_acc = 0.7680
# d-step 239 epoch 1 : .......... average_loss = 0.1823, train_acc = 0.9456, val_acc = 0.7890
# ДО ОБУЧЕНИЯ: val_acc = 0.7910
# d-step 240 epoch 1 : .......... average_loss = 0.1808, train_acc = 0.9455, val_acc = 0.7640
# ДО ОБУЧЕНИЯ: val_acc = 0.7690
# d-step 241 epoch 1 : .......... average_loss = 0.1748, train_acc = 0.9476, val_acc = 0.7940
# ДО ОБУЧЕНИЯ: val_acc = 0.7880
# d-step 242 epoch 1 : .......... average_loss = 0.1787, train_acc = 0.9476, val_acc = 0.7920
# ДО ОБУЧЕНИЯ: val_acc = 0.7960
# d-step 243 epoch 1 : .......... average_loss = 0.1747, train_acc = 0.9485, val_acc = 0.8100
# ДО ОБУЧЕНИЯ: val_acc = 0.8060
# d-step 244 epoch 1 : .......... average_loss = 0.1782, train_acc = 0.9475, val_acc = 0.7980
# ДО ОБУЧЕНИЯ: val_acc = 0.8060
# d-step 245 epoch 1 : .......... average_loss = 0.1775, train_acc = 0.9485, val_acc = 0.7890
# ДО ОБУЧЕНИЯ: val_acc = 0.7830
# d-step 246 epoch 1 : .......... average_loss = 0.1714, train_acc = 0.9504, val_acc = 0.7890
# ДО ОБУЧЕНИЯ: val_acc = 0.7890
# d-step 247 epoch 1 : .......... average_loss = 0.1737, train_acc = 0.9494, val_acc = 0.8010
# ДО ОБУЧЕНИЯ: val_acc = 0.8000
# d-step 248 epoch 1 : .......... average_loss = 0.1780, train_acc = 0.9484, val_acc = 0.8010
# ДО ОБУЧЕНИЯ: val_acc = 0.8000
# d-step 249 epoch 1 : .......... average_loss = 0.1730, train_acc = 0.9493, val_acc = 0.7710
# ДО ОБУЧЕНИЯ: val_acc = 0.7700
# d-step 250 epoch 1 : .......... average_loss = 0.1750, train_acc = 0.9492, val_acc = 0.7740
# ДО ОБУЧЕНИЯ: val_acc = 0.7730
# d-step 251 epoch 1 : .......... average_loss = 0.1703, train_acc = 0.9506, val_acc = 0.8050
# ДО ОБУЧЕНИЯ: val_acc = 0.8050
# d-step 252 epoch 1 : .......... average_loss = 0.1768, train_acc = 0.9496, val_acc = 0.7880
# ДО ОБУЧЕНИЯ: val_acc = 0.7880
# d-step 253 epoch 1 : .......... average_loss = 0.1725, train_acc = 0.9496, val_acc = 0.7870
# ДО ОБУЧЕНИЯ: val_acc = 0.7860
# d-step 254 epoch 1 : .......... average_loss = 0.1746, train_acc = 0.9495, val_acc = 0.8110
# ДО ОБУЧЕНИЯ: val_acc = 0.8120
# d-step 255 epoch 1 : .......... average_loss = 0.1760, train_acc = 0.9489, val_acc = 0.7880
# ДО ОБУЧЕНИЯ: val_acc = 0.7880
# d-step 256 epoch 1 : .......... average_loss = 0.1686, train_acc = 0.9510, val_acc = 0.7870
# ДО ОБУЧЕНИЯ: val_acc = 0.7850
# d-step 257 epoch 1 : .......... average_loss = 0.1781, train_acc = 0.9490, val_acc = 0.8030
# ДО ОБУЧЕНИЯ: val_acc = 0.8080
# d-step 258 epoch 1 : .......... average_loss = 0.1773, train_acc = 0.9486, val_acc = 0.7930
# ДО ОБУЧЕНИЯ: val_acc = 0.7950
# d-step 259 epoch 1 : .......... average_loss = 0.1732, train_acc = 0.9495, val_acc = 0.7870
# ДО ОБУЧЕНИЯ: val_acc = 0.7930
# d-step 260 epoch 1 : .......... average_loss = 0.1739, train_acc = 0.9478, val_acc = 0.7970
# ДО ОБУЧЕНИЯ: val_acc = 0.8020
# d-step 261 epoch 1 : .......... average_loss = 0.1758, train_acc = 0.9505, val_acc = 0.8040
# ДО ОБУЧЕНИЯ: val_acc = 0.8020
# d-step 262 epoch 1 : .......... average_loss = 0.1702, train_acc = 0.9508, val_acc = 0.8150
# ДО ОБУЧЕНИЯ: val_acc = 0.8100
# d-step 263 epoch 1 : .......... average_loss = 0.1865, train_acc = 0.9457, val_acc = 0.8040
# ДО ОБУЧЕНИЯ: val_acc = 0.8090
# d-step 264 epoch 1 : .......... average_loss = 0.1557, train_acc = 0.9565, val_acc = 0.7820
# ДО ОБУЧЕНИЯ: val_acc = 0.7820
# d-step 265 epoch 1 : .......... average_loss = 0.1687, train_acc = 0.9522, val_acc = 0.8010
# ДО ОБУЧЕНИЯ: val_acc = 0.7940
# d-step 266 epoch 1 : .......... average_loss = 0.1701, train_acc = 0.9494, val_acc = 0.7970
# ДО ОБУЧЕНИЯ: val_acc = 0.8000
# d-step 267 epoch 1 : .......... average_loss = 0.1696, train_acc = 0.9504, val_acc = 0.7700
# ДО ОБУЧЕНИЯ: val_acc = 0.7700
# d-step 268 epoch 1 : .......... average_loss = 0.1677, train_acc = 0.9522, val_acc = 0.7920
# ДО ОБУЧЕНИЯ: val_acc = 0.7950
# d-step 269 epoch 1 : .......... average_loss = 0.1600, train_acc = 0.9542, val_acc = 0.7990
# ДО ОБУЧЕНИЯ: val_acc = 0.8030
# d-step 270 epoch 1 : .......... average_loss = 0.1674, train_acc = 0.9517, val_acc = 0.7940
# ДО ОБУЧЕНИЯ: val_acc = 0.7950
# d-step 271 epoch 1 : .......... average_loss = 0.1699, train_acc = 0.9512, val_acc = 0.7470
# ДО ОБУЧЕНИЯ: val_acc = 0.7430
# d-step 272 epoch 1 : .......... average_loss = 0.1707, train_acc = 0.9510, val_acc = 0.8020
# ДО ОБУЧЕНИЯ: val_acc = 0.7990
# d-step 273 epoch 1 : .......... average_loss = 0.1719, train_acc = 0.9508, val_acc = 0.7940
# ДО ОБУЧЕНИЯ: val_acc = 0.7980
# d-step 274 epoch 1 : .......... average_loss = 0.1705, train_acc = 0.9506, val_acc = 0.8020
# ДО ОБУЧЕНИЯ: val_acc = 0.7980
# d-step 275 epoch 1 : .......... average_loss = 0.1688, train_acc = 0.9515, val_acc = 0.8000
# ДО ОБУЧЕНИЯ: val_acc = 0.7990
# d-step 276 epoch 1 : .......... average_loss = 0.1656, train_acc = 0.9524, val_acc = 0.7900
# ДО ОБУЧЕНИЯ: val_acc = 0.7850
# d-step 277 epoch 1 : .......... average_loss = 0.1657, train_acc = 0.9531, val_acc = 0.7960
# ДО ОБУЧЕНИЯ: val_acc = 0.7970
# d-step 278 epoch 1 : .......... average_loss = 0.1659, train_acc = 0.9526, val_acc = 0.7470
# ДО ОБУЧЕНИЯ: val_acc = 0.7410
# d-step 279 epoch 1 : .......... average_loss = 0.1710, train_acc = 0.9516, val_acc = 0.8000
# ДО ОБУЧЕНИЯ: val_acc = 0.7960
# d-step 280 epoch 1 : .......... average_loss = 0.1598, train_acc = 0.9542, val_acc = 0.8100
# ДО ОБУЧЕНИЯ: val_acc = 0.8070
# d-step 281 epoch 1 : .......... average_loss = 0.1683, train_acc = 0.9514, val_acc = 0.8030
# ДО ОБУЧЕНИЯ: val_acc = 0.8010
# d-step 282 epoch 1 : .......... average_loss = 0.1600, train_acc = 0.9552, val_acc = 0.7820
# ДО ОБУЧЕНИЯ: val_acc = 0.7830
# d-step 283 epoch 1 : .......... average_loss = 0.1689, train_acc = 0.9519, val_acc = 0.8050
# ДО ОБУЧЕНИЯ: val_acc = 0.8050
# d-step 284 epoch 1 : .......... average_loss = 0.1699, train_acc = 0.9516, val_acc = 0.8170
# ДО ОБУЧЕНИЯ: val_acc = 0.8120
# d-step 285 epoch 1 : .......... average_loss = 0.1630, train_acc = 0.9523, val_acc = 0.8160
# ДО ОБУЧЕНИЯ: val_acc = 0.8110
# d-step 286 epoch 1 : .......... average_loss = 0.1677, train_acc = 0.9516, val_acc = 0.8200
# ДО ОБУЧЕНИЯ: val_acc = 0.8180
# d-step 287 epoch 1 : .......... average_loss = 0.1617, train_acc = 0.9537, val_acc = 0.8030
# ДО ОБУЧЕНИЯ: val_acc = 0.8070
# d-step 288 epoch 1 : .......... average_loss = 0.1652, train_acc = 0.9531, val_acc = 0.8060
# ДО ОБУЧЕНИЯ: val_acc = 0.8070
# d-step 289 epoch 1 : .......... average_loss = 0.1632, train_acc = 0.9537, val_acc = 0.7730
# ДО ОБУЧЕНИЯ: val_acc = 0.7720
# d-step 290 epoch 1 : .......... average_loss = 0.1652, train_acc = 0.9536, val_acc = 0.8040
# ДО ОБУЧЕНИЯ: val_acc = 0.7990
# d-step 291 epoch 1 : .......... average_loss = 0.1597, train_acc = 0.9551, val_acc = 0.7790
# ДО ОБУЧЕНИЯ: val_acc = 0.7870
# d-step 292 epoch 1 : .......... average_loss = 0.1621, train_acc = 0.9547, val_acc = 0.8120
# ДО ОБУЧЕНИЯ: val_acc = 0.8060
# d-step 293 epoch 1 : .......... average_loss = 0.1605, train_acc = 0.9547, val_acc = 0.7930
# ДО ОБУЧЕНИЯ: val_acc = 0.7970
# d-step 294 epoch 1 : .......... average_loss = 0.1659, train_acc = 0.9529, val_acc = 0.8120
# ДО ОБУЧЕНИЯ: val_acc = 0.8140
# d-step 295 epoch 1 : .......... average_loss = 0.1689, train_acc = 0.9515, val_acc = 0.7690
# ДО ОБУЧЕНИЯ: val_acc = 0.7720
# d-step 296 epoch 1 : .......... average_loss = 0.1690, train_acc = 0.9514, val_acc = 0.8100
# ДО ОБУЧЕНИЯ: val_acc = 0.8100
# d-step 297 epoch 1 : .......... average_loss = 0.1659, train_acc = 0.9529, val_acc = 0.8260
# ДО ОБУЧЕНИЯ: val_acc = 0.8250
# d-step 298 epoch 1 : .......... average_loss = 0.1611, train_acc = 0.9543, val_acc = 0.8100
# ДО ОБУЧЕНИЯ: val_acc = 0.8160
# d-step 299 epoch 1 : .......... average_loss = 0.1656, train_acc = 0.9528, val_acc = 0.8180
# ДО ОБУЧЕНИЯ: val_acc = 0.8130
# d-step 300 epoch 1 : .......... average_loss = 0.1621, train_acc = 0.9529, val_acc = 0.8000
# CPU times: user 7min 45s, sys: 3min 42s, total: 11min 27s
# Wall time: 11min 33s

# %% [markdown]
# Состязательное обучение. Обучение генератора на основе обучения с подкреплением

# %%
test_mle(gen, data_file_tensor_train, data_file_tensor_test)
# average_train_NLL = 1.7516 average_test_NLL = 1.9832
# Out:
# average_train_NLL = 1.8009 average_test_NLL = 1.9609

# %%
# %%time
# gen_optimizer = optim.Adagrad(gen.parameters(), lr=0.0005)#Adam #, lr=0.0005
# dis_optimizer = optim.Adagrad(dis.parameters())
# gen_optimizer = optim.Adam(gen.parameters(), lr=0.0001)#Adam #, lr=0.0005
# dis_optimizer = optim.Adagrad(dis.parameters(), lr=0.001)#, lr=0.002

# состязательное обучение генератора
print('\nStarting Adversarial Training...')

for epoch in range(ADV_TRAIN_EPOCHS):# ADV_TRAIN_EPOCHS
    print('\n--------\nEPOCH %d\n--------' % (epoch+1))
    # обучение генератора
    print('\nAdversarial Training Generator : ', end='')
    train_generator_PG(gen, gen_optimizer, dis, 1)#

    # тестирование nll
    print('\nTesting Generator : ', end='')
    test_mle(gen, data_file_tensor_train, data_file_tensor_test)

    # обучение дискриминатора
    print('\nAdversarial Training Discriminator : ')
    train_discriminator(dis, dis_optimizer, data_file_tensor_train, gen, 5, 1)#3, 1

# сохранение результата обучения
save_models(data_file_tensor_train, gen, dis, gen_optimizer, dis_optimizer,
            FILE_PATHS['saved_models'] + r'/' + r'seqgan_adversarial_training.pytorch')
# epoch 3 : .......... average_train_NLL = 1.8005 average_test_NLL = 1.9824
# average_train_NLL = 1.7340 average_test_NLL = 2.0599
# Out:
# Starting Adversarial Training...
#
# --------
# EPOCH 1
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8014 average_test_NLL = 1.9606
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.8010
# d-step 1 epoch 1 : .......... average_loss = 0.1623, train_acc = 0.9534, val_acc = 0.8070
# ДО ОБУЧЕНИЯ: val_acc = 0.8120
# d-step 2 epoch 1 : .......... average_loss = 0.1551, train_acc = 0.9574, val_acc = 0.7940
# ДО ОБУЧЕНИЯ: val_acc = 0.7980
# d-step 3 epoch 1 : .......... average_loss = 0.1643, train_acc = 0.9532, val_acc = 0.8080
# ДО ОБУЧЕНИЯ: val_acc = 0.8000
# d-step 4 epoch 1 : .......... average_loss = 0.1640, train_acc = 0.9532, val_acc = 0.8010
# ДО ОБУЧЕНИЯ: val_acc = 0.7960
# d-step 5 epoch 1 : .......... average_loss = 0.1642, train_acc = 0.9534, val_acc = 0.8040
#
# --------
# EPOCH 2
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8021 average_test_NLL = 1.9603
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.8290
# d-step 1 epoch 1 : .......... average_loss = 0.1582, train_acc = 0.9560, val_acc = 0.8010
# ДО ОБУЧЕНИЯ: val_acc = 0.8000
# d-step 2 epoch 1 : .......... average_loss = 0.1637, train_acc = 0.9543, val_acc = 0.8190
# ДО ОБУЧЕНИЯ: val_acc = 0.8150
# d-step 3 epoch 1 : .......... average_loss = 0.1594, train_acc = 0.9550, val_acc = 0.8160
# ДО ОБУЧЕНИЯ: val_acc = 0.8180
# d-step 4 epoch 1 : .......... average_loss = 0.1580, train_acc = 0.9549, val_acc = 0.8040
# ДО ОБУЧЕНИЯ: val_acc = 0.8050
# d-step 5 epoch 1 : .......... average_loss = 0.1595, train_acc = 0.9554, val_acc = 0.8230
#
# --------
# EPOCH 3
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8028 average_test_NLL = 1.9602
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.8290
# d-step 1 epoch 1 : .......... average_loss = 0.1570, train_acc = 0.9555, val_acc = 0.8370
# ДО ОБУЧЕНИЯ: val_acc = 0.8450
# d-step 2 epoch 1 : .......... average_loss = 0.1633, train_acc = 0.9530, val_acc = 0.8310
# ДО ОБУЧЕНИЯ: val_acc = 0.8260
# d-step 3 epoch 1 : .......... average_loss = 0.1578, train_acc = 0.9544, val_acc = 0.7950
# ДО ОБУЧЕНИЯ: val_acc = 0.8040
# d-step 4 epoch 1 : .......... average_loss = 0.1644, train_acc = 0.9536, val_acc = 0.8270
# ДО ОБУЧЕНИЯ: val_acc = 0.8290
# d-step 5 epoch 1 : .......... average_loss = 0.1606, train_acc = 0.9546, val_acc = 0.8230
#
# --------
# EPOCH 4
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8034 average_test_NLL = 1.9602
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.8030
# d-step 1 epoch 1 : .......... average_loss = 0.1551, train_acc = 0.9563, val_acc = 0.8010
# ДО ОБУЧЕНИЯ: val_acc = 0.8000
# d-step 2 epoch 1 : .......... average_loss = 0.1573, train_acc = 0.9556, val_acc = 0.7970
# ДО ОБУЧЕНИЯ: val_acc = 0.8020
# d-step 3 epoch 1 : .......... average_loss = 0.1503, train_acc = 0.9584, val_acc = 0.8000
# ДО ОБУЧЕНИЯ: val_acc = 0.7980
# d-step 4 epoch 1 : .......... average_loss = 0.1630, train_acc = 0.9526, val_acc = 0.7880
# ДО ОБУЧЕНИЯ: val_acc = 0.7940
# d-step 5 epoch 1 : .......... average_loss = 0.1543, train_acc = 0.9562, val_acc = 0.7620
#
# --------
# EPOCH 5
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8040 average_test_NLL = 1.9601
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.7770
# d-step 1 epoch 1 : .......... average_loss = 0.1589, train_acc = 0.9558, val_acc = 0.8230
# ДО ОБУЧЕНИЯ: val_acc = 0.8180
# d-step 2 epoch 1 : .......... average_loss = 0.1537, train_acc = 0.9568, val_acc = 0.8300
# ДО ОБУЧЕНИЯ: val_acc = 0.8350
# d-step 3 epoch 1 : .......... average_loss = 0.1554, train_acc = 0.9559, val_acc = 0.7620
# ДО ОБУЧЕНИЯ: val_acc = 0.7600
# d-step 4 epoch 1 : .......... average_loss = 0.1604, train_acc = 0.9550, val_acc = 0.8030
# ДО ОБУЧЕНИЯ: val_acc = 0.8010
# d-step 5 epoch 1 : .......... average_loss = 0.1587, train_acc = 0.9552, val_acc = 0.8130
#
# --------
# EPOCH 6
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8045 average_test_NLL = 1.9600
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.7940
# d-step 1 epoch 1 : .......... average_loss = 0.1539, train_acc = 0.9563, val_acc = 0.7900
# ДО ОБУЧЕНИЯ: val_acc = 0.7910
# d-step 2 epoch 1 : .......... average_loss = 0.1595, train_acc = 0.9540, val_acc = 0.7960
# ДО ОБУЧЕНИЯ: val_acc = 0.7970
# d-step 3 epoch 1 : .......... average_loss = 0.1592, train_acc = 0.9553, val_acc = 0.7960
# ДО ОБУЧЕНИЯ: val_acc = 0.7950
# d-step 4 epoch 1 : .......... average_loss = 0.1546, train_acc = 0.9561, val_acc = 0.7990
# ДО ОБУЧЕНИЯ: val_acc = 0.8050
# d-step 5 epoch 1 : .......... average_loss = 0.1517, train_acc = 0.9577, val_acc = 0.8150
#
# --------
# EPOCH 7
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8048 average_test_NLL = 1.9599
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.8270
# d-step 1 epoch 1 : .......... average_loss = 0.1576, train_acc = 0.9545, val_acc = 0.8130
# ДО ОБУЧЕНИЯ: val_acc = 0.8110
# d-step 2 epoch 1 : .......... average_loss = 0.1517, train_acc = 0.9576, val_acc = 0.8270
# ДО ОБУЧЕНИЯ: val_acc = 0.8230
# d-step 3 epoch 1 : .......... average_loss = 0.1535, train_acc = 0.9566, val_acc = 0.8120
# ДО ОБУЧЕНИЯ: val_acc = 0.8220
# d-step 4 epoch 1 : .......... average_loss = 0.1529, train_acc = 0.9569, val_acc = 0.8180
# ДО ОБУЧЕНИЯ: val_acc = 0.8190
# d-step 5 epoch 1 : .......... average_loss = 0.1569, train_acc = 0.9567, val_acc = 0.8070
#
# --------
# EPOCH 8
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8051 average_test_NLL = 1.9598
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.8150
# d-step 1 epoch 1 : .......... average_loss = 0.1490, train_acc = 0.9579, val_acc = 0.8420
# ДО ОБУЧЕНИЯ: val_acc = 0.8370
# d-step 2 epoch 1 : .......... average_loss = 0.1563, train_acc = 0.9560, val_acc = 0.8140
# ДО ОБУЧЕНИЯ: val_acc = 0.8120
# d-step 3 epoch 1 : .......... average_loss = 0.1572, train_acc = 0.9553, val_acc = 0.8160
# ДО ОБУЧЕНИЯ: val_acc = 0.8150
# d-step 4 epoch 1 : .......... average_loss = 0.1522, train_acc = 0.9571, val_acc = 0.8230
# ДО ОБУЧЕНИЯ: val_acc = 0.8210
# d-step 5 epoch 1 : .......... average_loss = 0.1534, train_acc = 0.9570, val_acc = 0.8340
#
# --------
# EPOCH 9
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8052 average_test_NLL = 1.9595
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.8300
# d-step 1 epoch 1 : .......... average_loss = 0.1590, train_acc = 0.9539, val_acc = 0.8440
# ДО ОБУЧЕНИЯ: val_acc = 0.8380
# d-step 2 epoch 1 : .......... average_loss = 0.1550, train_acc = 0.9553, val_acc = 0.8070
# ДО ОБУЧЕНИЯ: val_acc = 0.8100
# d-step 3 epoch 1 : .......... average_loss = 0.1561, train_acc = 0.9554, val_acc = 0.8360
# ДО ОБУЧЕНИЯ: val_acc = 0.8320
# d-step 4 epoch 1 : .......... average_loss = 0.1560, train_acc = 0.9564, val_acc = 0.8190
# ДО ОБУЧЕНИЯ: val_acc = 0.8190
# d-step 5 epoch 1 : .......... average_loss = 0.1515, train_acc = 0.9577, val_acc = 0.7950
#
# --------
# EPOCH 10
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8052 average_test_NLL = 1.9592
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.7970
# d-step 1 epoch 1 : .......... average_loss = 0.1544, train_acc = 0.9569, val_acc = 0.8050
# ДО ОБУЧЕНИЯ: val_acc = 0.8050
# d-step 2 epoch 1 : .......... average_loss = 0.1540, train_acc = 0.9550, val_acc = 0.8400
# ДО ОБУЧЕНИЯ: val_acc = 0.8430
# d-step 3 epoch 1 : .......... average_loss = 0.1550, train_acc = 0.9554, val_acc = 0.8280
# ДО ОБУЧЕНИЯ: val_acc = 0.8230
# d-step 4 epoch 1 : .......... average_loss = 0.1563, train_acc = 0.9565, val_acc = 0.8480
# ДО ОБУЧЕНИЯ: val_acc = 0.8430
# d-step 5 epoch 1 : .......... average_loss = 0.1523, train_acc = 0.9571, val_acc = 0.8290
#
# --------
# EPOCH 11
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8051 average_test_NLL = 1.9589
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.7970
# d-step 1 epoch 1 : .......... average_loss = 0.1590, train_acc = 0.9547, val_acc = 0.8120
# ДО ОБУЧЕНИЯ: val_acc = 0.8080
# d-step 2 epoch 1 : .......... average_loss = 0.1558, train_acc = 0.9554, val_acc = 0.8060
# ДО ОБУЧЕНИЯ: val_acc = 0.8010
# d-step 3 epoch 1 : .......... average_loss = 0.1604, train_acc = 0.9539, val_acc = 0.8000
# ДО ОБУЧЕНИЯ: val_acc = 0.8010
# d-step 4 epoch 1 : .......... average_loss = 0.1556, train_acc = 0.9559, val_acc = 0.8110
# ДО ОБУЧЕНИЯ: val_acc = 0.8060
# d-step 5 epoch 1 : .......... average_loss = 0.1522, train_acc = 0.9577, val_acc = 0.8120
#
# --------
# EPOCH 12
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8049 average_test_NLL = 1.9585
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.8170
# d-step 1 epoch 1 : .......... average_loss = 0.1576, train_acc = 0.9559, val_acc = 0.8160
# ДО ОБУЧЕНИЯ: val_acc = 0.8260
# d-step 2 epoch 1 : .......... average_loss = 0.1568, train_acc = 0.9552, val_acc = 0.8150
# ДО ОБУЧЕНИЯ: val_acc = 0.8150
# d-step 3 epoch 1 : .......... average_loss = 0.1568, train_acc = 0.9560, val_acc = 0.8030
# ДО ОБУЧЕНИЯ: val_acc = 0.8070
# d-step 4 epoch 1 : .......... average_loss = 0.1497, train_acc = 0.9582, val_acc = 0.7780
# ДО ОБУЧЕНИЯ: val_acc = 0.7770
# d-step 5 epoch 1 : .......... average_loss = 0.1561, train_acc = 0.9561, val_acc = 0.8180
#
# --------
# EPOCH 13
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8047 average_test_NLL = 1.9581
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.8190
# d-step 1 epoch 1 : .......... average_loss = 0.1599, train_acc = 0.9556, val_acc = 0.8240
# ДО ОБУЧЕНИЯ: val_acc = 0.8220
# d-step 2 epoch 1 : .......... average_loss = 0.1540, train_acc = 0.9562, val_acc = 0.8140
# ДО ОБУЧЕНИЯ: val_acc = 0.8160
# d-step 3 epoch 1 : .......... average_loss = 0.1586, train_acc = 0.9544, val_acc = 0.8030
# ДО ОБУЧЕНИЯ: val_acc = 0.8030
# d-step 4 epoch 1 : .......... average_loss = 0.1603, train_acc = 0.9542, val_acc = 0.7990
# ДО ОБУЧЕНИЯ: val_acc = 0.8000
# d-step 5 epoch 1 : .......... average_loss = 0.1617, train_acc = 0.9530, val_acc = 0.8100
#
# --------
# EPOCH 14
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8044 average_test_NLL = 1.9578
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.7870
# d-step 1 epoch 1 : .......... average_loss = 0.1559, train_acc = 0.9557, val_acc = 0.7990
# ДО ОБУЧЕНИЯ: val_acc = 0.7990
# d-step 2 epoch 1 : .......... average_loss = 0.1566, train_acc = 0.9547, val_acc = 0.8130
# ДО ОБУЧЕНИЯ: val_acc = 0.8150
# d-step 3 epoch 1 : .......... average_loss = 0.1608, train_acc = 0.9534, val_acc = 0.8040
# ДО ОБУЧЕНИЯ: val_acc = 0.8060
# d-step 4 epoch 1 : .......... average_loss = 0.1547, train_acc = 0.9568, val_acc = 0.8110
# ДО ОБУЧЕНИЯ: val_acc = 0.8070
# d-step 5 epoch 1 : .......... average_loss = 0.1564, train_acc = 0.9558, val_acc = 0.8000
#
# --------
# EPOCH 15
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8042 average_test_NLL = 1.9574
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.8160
# d-step 1 epoch 1 : .......... average_loss = 0.1534, train_acc = 0.9562, val_acc = 0.8220
# ДО ОБУЧЕНИЯ: val_acc = 0.8240
# d-step 2 epoch 1 : .......... average_loss = 0.1546, train_acc = 0.9561, val_acc = 0.8060
# ДО ОБУЧЕНИЯ: val_acc = 0.8080
# d-step 3 epoch 1 : .......... average_loss = 0.1581, train_acc = 0.9550, val_acc = 0.8220
# ДО ОБУЧЕНИЯ: val_acc = 0.8240
# d-step 4 epoch 1 : .......... average_loss = 0.1616, train_acc = 0.9535, val_acc = 0.8110
# ДО ОБУЧЕНИЯ: val_acc = 0.8110
# d-step 5 epoch 1 : .......... average_loss = 0.1531, train_acc = 0.9575, val_acc = 0.8290
#
# --------
# EPOCH 16
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8039 average_test_NLL = 1.9571
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.8280
# d-step 1 epoch 1 : .......... average_loss = 0.1629, train_acc = 0.9528, val_acc = 0.7910
# ДО ОБУЧЕНИЯ: val_acc = 0.7930
# d-step 2 epoch 1 : .......... average_loss = 0.1596, train_acc = 0.9546, val_acc = 0.8270
# ДО ОБУЧЕНИЯ: val_acc = 0.8240
# d-step 3 epoch 1 : .......... average_loss = 0.1547, train_acc = 0.9553, val_acc = 0.8250
# ДО ОБУЧЕНИЯ: val_acc = 0.8290
# d-step 4 epoch 1 : .......... average_loss = 0.1557, train_acc = 0.9555, val_acc = 0.8150
# ДО ОБУЧЕНИЯ: val_acc = 0.8160
# d-step 5 epoch 1 : .......... average_loss = 0.1600, train_acc = 0.9540, val_acc = 0.8260
#
# --------
# EPOCH 17
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8036 average_test_NLL = 1.9568
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.8220
# d-step 1 epoch 1 : .......... average_loss = 0.1538, train_acc = 0.9559, val_acc = 0.8150
# ДО ОБУЧЕНИЯ: val_acc = 0.8210
# d-step 2 epoch 1 : .......... average_loss = 0.1550, train_acc = 0.9565, val_acc = 0.8220
# ДО ОБУЧЕНИЯ: val_acc = 0.8320
# d-step 3 epoch 1 : .......... average_loss = 0.1557, train_acc = 0.9554, val_acc = 0.8180
# ДО ОБУЧЕНИЯ: val_acc = 0.8230
# d-step 4 epoch 1 : .......... average_loss = 0.1569, train_acc = 0.9553, val_acc = 0.7800
# ДО ОБУЧЕНИЯ: val_acc = 0.7870
# d-step 5 epoch 1 : .......... average_loss = 0.1570, train_acc = 0.9544, val_acc = 0.8170
#
# --------
# EPOCH 18
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8034 average_test_NLL = 1.9565
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.7980
# d-step 1 epoch 1 : .......... average_loss = 0.1560, train_acc = 0.9550, val_acc = 0.8090
# ДО ОБУЧЕНИЯ: val_acc = 0.8110
# d-step 2 epoch 1 : .......... average_loss = 0.1517, train_acc = 0.9562, val_acc = 0.7970
# ДО ОБУЧЕНИЯ: val_acc = 0.7930
# d-step 3 epoch 1 : .......... average_loss = 0.1565, train_acc = 0.9555, val_acc = 0.7790
# ДО ОБУЧЕНИЯ: val_acc = 0.7760
# d-step 4 epoch 1 : .......... average_loss = 0.1662, train_acc = 0.9516, val_acc = 0.8060
# ДО ОБУЧЕНИЯ: val_acc = 0.7990
# d-step 5 epoch 1 : .......... average_loss = 0.1479, train_acc = 0.9581, val_acc = 0.7690
#
# --------
# EPOCH 19
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8031 average_test_NLL = 1.9562
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.7860
# d-step 1 epoch 1 : .......... average_loss = 0.1604, train_acc = 0.9528, val_acc = 0.8190
# ДО ОБУЧЕНИЯ: val_acc = 0.8230
# d-step 2 epoch 1 : .......... average_loss = 0.1561, train_acc = 0.9559, val_acc = 0.8040
# ДО ОБУЧЕНИЯ: val_acc = 0.7990
# d-step 3 epoch 1 : .......... average_loss = 0.1498, train_acc = 0.9577, val_acc = 0.8390
# ДО ОБУЧЕНИЯ: val_acc = 0.8260
# d-step 4 epoch 1 : .......... average_loss = 0.1554, train_acc = 0.9548, val_acc = 0.8180
# ДО ОБУЧЕНИЯ: val_acc = 0.8210
# d-step 5 epoch 1 : .......... average_loss = 0.1575, train_acc = 0.9547, val_acc = 0.7870
#
# --------
# EPOCH 20
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8028 average_test_NLL = 1.9559
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.7760
# d-step 1 epoch 1 : .......... average_loss = 0.1579, train_acc = 0.9544, val_acc = 0.8070
# ДО ОБУЧЕНИЯ: val_acc = 0.8060
# d-step 2 epoch 1 : .......... average_loss = 0.1572, train_acc = 0.9554, val_acc = 0.8210
# ДО ОБУЧЕНИЯ: val_acc = 0.8140
# d-step 3 epoch 1 : .......... average_loss = 0.1642, train_acc = 0.9519, val_acc = 0.8000
# ДО ОБУЧЕНИЯ: val_acc = 0.7990
# d-step 4 epoch 1 : .......... average_loss = 0.1578, train_acc = 0.9544, val_acc = 0.7970
# ДО ОБУЧЕНИЯ: val_acc = 0.7980
# d-step 5 epoch 1 : .......... average_loss = 0.1569, train_acc = 0.9551, val_acc = 0.7880
#
# --------
# EPOCH 21
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8024 average_test_NLL = 1.9556
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.8000
# d-step 1 epoch 1 : .......... average_loss = 0.1614, train_acc = 0.9533, val_acc = 0.8170
# ДО ОБУЧЕНИЯ: val_acc = 0.8170
# d-step 2 epoch 1 : .......... average_loss = 0.1586, train_acc = 0.9553, val_acc = 0.8180
# ДО ОБУЧЕНИЯ: val_acc = 0.8210
# d-step 3 epoch 1 : .......... average_loss = 0.1566, train_acc = 0.9557, val_acc = 0.8200
# ДО ОБУЧЕНИЯ: val_acc = 0.8100
# d-step 4 epoch 1 : .......... average_loss = 0.1580, train_acc = 0.9540, val_acc = 0.7530
# ДО ОБУЧЕНИЯ: val_acc = 0.7560
# d-step 5 epoch 1 : .......... average_loss = 0.1617, train_acc = 0.9536, val_acc = 0.8140
#
# --------
# EPOCH 22
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8021 average_test_NLL = 1.9553
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.8200
# d-step 1 epoch 1 : .......... average_loss = 0.1614, train_acc = 0.9525, val_acc = 0.7630
# ДО ОБУЧЕНИЯ: val_acc = 0.7690
# d-step 2 epoch 1 : .......... average_loss = 0.1592, train_acc = 0.9528, val_acc = 0.7960
# ДО ОБУЧЕНИЯ: val_acc = 0.7930
# d-step 3 epoch 1 : .......... average_loss = 0.1587, train_acc = 0.9532, val_acc = 0.8320
# ДО ОБУЧЕНИЯ: val_acc = 0.8230
# d-step 4 epoch 1 : .......... average_loss = 0.1557, train_acc = 0.9542, val_acc = 0.8170
# ДО ОБУЧЕНИЯ: val_acc = 0.8170
# d-step 5 epoch 1 : .......... average_loss = 0.1636, train_acc = 0.9523, val_acc = 0.8260
#
# --------
# EPOCH 23
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8018 average_test_NLL = 1.9550
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.8310
# d-step 1 epoch 1 : .......... average_loss = 0.1585, train_acc = 0.9538, val_acc = 0.8190
# ДО ОБУЧЕНИЯ: val_acc = 0.8210
# d-step 2 epoch 1 : .......... average_loss = 0.1647, train_acc = 0.9518, val_acc = 0.8150
# ДО ОБУЧЕНИЯ: val_acc = 0.8160
# d-step 3 epoch 1 : .......... average_loss = 0.1622, train_acc = 0.9523, val_acc = 0.8080
# ДО ОБУЧЕНИЯ: val_acc = 0.8040
# d-step 4 epoch 1 : .......... average_loss = 0.1622, train_acc = 0.9531, val_acc = 0.7860
# ДО ОБУЧЕНИЯ: val_acc = 0.7880
# d-step 5 epoch 1 : .......... average_loss = 0.1589, train_acc = 0.9541, val_acc = 0.8120
#
# --------
# EPOCH 24
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8015 average_test_NLL = 1.9547
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.7690
# d-step 1 epoch 1 : .......... average_loss = 0.1622, train_acc = 0.9534, val_acc = 0.7870
# ДО ОБУЧЕНИЯ: val_acc = 0.7840
# d-step 2 epoch 1 : .......... average_loss = 0.1612, train_acc = 0.9526, val_acc = 0.7680
# ДО ОБУЧЕНИЯ: val_acc = 0.7650
# d-step 3 epoch 1 : .......... average_loss = 0.1583, train_acc = 0.9536, val_acc = 0.7700
# ДО ОБУЧЕНИЯ: val_acc = 0.7720
# d-step 4 epoch 1 : .......... average_loss = 0.1602, train_acc = 0.9540, val_acc = 0.7900
# ДО ОБУЧЕНИЯ: val_acc = 0.7880
# d-step 5 epoch 1 : .......... average_loss = 0.1626, train_acc = 0.9519, val_acc = 0.7790
#
# --------
# EPOCH 25
# --------
#
# Adversarial Training Generator :
#
# Testing Generator : average_train_NLL = 1.8011 average_test_NLL = 1.9544
#
# Adversarial Training Discriminator :
# ДО ОБУЧЕНИЯ: val_acc = 0.8030
# d-step 1 epoch 1 : .......... average_loss = 0.1545, train_acc = 0.9564, val_acc = 0.8060
# ДО ОБУЧЕНИЯ: val_acc = 0.7980
# d-step 2 epoch 1 : .......... average_loss = 0.1553, train_acc = 0.9554, val_acc = 0.7880
# ДО ОБУЧЕНИЯ: val_acc = 0.7870
# d-step 3 epoch 1 : .......... average_loss = 0.1577, train_acc = 0.9543, val_acc = 0.7640
# ДО ОБУЧЕНИЯ: val_acc = 0.7620
# d-step 4 epoch 1 : .......... average_loss = 0.1584, train_acc = 0.9536, val_acc = 0.8080
# ДО ОБУЧЕНИЯ: val_acc = 0.8120
# d-step 5 epoch 1 : .......... average_loss = 0.1661, train_acc = 0.9518, val_acc = 0.8130
# CPU times: user 30min 56s, sys: 21min 7s, total: 52min 4s
# Wall time: 52min 7s

# %% [markdown]
# Тестирование генератора на обучающей выборке после состязательного обучения.

# %%
# %%time
test_mle(gen, data_file_tensor_train, data_file_tensor_test)
# average_train_NLL = 1.5186 average_test_NLL = 2.0730
# average_train_NLL = 1.4459 average_test_NLL = 1.9926
# Out:
# average_train_NLL = 1.8011 average_test_NLL = 1.9544
# CPU times: user 1.41 s, sys: 395 ms, total: 1.81 s
# Wall time: 1.81 s

# %% [markdown]
# Генерация примеров текстов на основе SeqGAN

# %%
# примеры сгенерированных текстов
print("Примеры генерируемых текстов на основе SeqGAN")
degree = 1
print("Degree:", degree)
samples = gen.sample(50, degree=degree).cpu().detach().numpy()

output_function = []
for i, samp in enumerate(samples):
  line = [word[x] for x in samp]
  line = ' '.join(line)
  output_function.append(line)
  bleu = BLEU(data_file_test.tolist(), [samp], flag_print=False)
  print("#", i, "\tПример: ", line, ' '*(100-len(line)), '\tОценка: ', bleu)
# Out:
# Примеры генерируемых текстов на основе SeqGAN
# Degree: 1
# # 0 	Пример:  A very pretty blue flowered bus waiting for the city .                                                	Оценка:  [0.39735970711951313, 0.29744417462950146, 0.11154288433080788, 0.06268007390554406]
# # 1 	Пример:  a Children are playing a video game on a sink that is sitting next to construction .                  	Оценка:  [0.7015021476502369, 0.47820615913318404, 0.28320384389628483, 0.13208555288986817]
# # 2 	Пример:  This plate contains meat sandwich and silverware is sitting and a pot in the water .                  	Оценка:  [0.6155870112510925, 0.4721631957086835, 0.28051550320162943, 0.13108152886996202]
# # 3 	Пример:  A computer monitor is with pillows , a checkered box .                                                	Оценка:  [0.3627381250550058, 0.19407576238520263, 0.08097785064266204, 0.048514214015354815]
# # 4 	Пример:  A kitchen that close up oven inside of a flat wall .                                                  	Оценка:  [0.4701623459816272, 0.2906817235909849, 0.10963546543618267, 0.06182111806058444]
# # 5 	Пример:  A man in the middle of a surfboard in a kitchen .                                                     	Оценка:  [0.5893796917545019, 0.536458262707534, 0.43657083720498996, 0.29595097886811256]
# # 6 	Пример:  A man who is flying a kite kite standing in the parking lot .                                         	Оценка:  [0.6366028258614133, 0.5647438827324667, 0.45372365197359754, 0.3052172947188026]
# # 7 	Пример:  Two people sitting in front of a living room table with furniture and a flat screen TV .              	Оценка:  [0.8973645624241783, 0.8347111709131683, 0.6431058201682329, 0.4034613668291822]
# # 8 	Пример:  A cross country skier in a golf setting on the same city .                                            	Оценка:  [0.39735970711951313, 0.0957263977058556, 0.0476608251305123, 0.03174718691298666]
# # 9 	Пример:  A dog appears to be neatly made with a laptop monitor .                                               	Оценка:  [0.435285750066007, 0.2761227119166927, 0.10549074689987335, 0.059944245366591306]
# # 10 	Пример:  A little kid on a recliner on a wooden floor .                                                        	Оценка:  [0.45014617508912413, 0.3557663528269982, 0.2697856975860103, 0.20136831744308098]
# # 11 	Пример:  A Many kites fly flying over a fallen kite .                                                          	Оценка:  [0.32444284226152503, 0.1801639783124087, 0.07658412276041004, 0.046396689848933415]
# # 12 	Пример:  A bunch of people riding a bike down a street .                                                       	Оценка:  [0.5380275868489703, 0.5048265531987134, 0.4410490727311681, 0.34274531986654627]
# # 13 	Пример:  A woman holding a hat while sitting on a table .                                                      	Оценка:  [0.5104177855340404, 0.44283653888216973, 0.37808143557096185, 0.2637814711838711]
# # 14 	Пример:  A duck foal on a little girl on a lap .                                                               	Оценка:  [0.4588314677411235, 0.28599248869989347, 0.10830630507021792, 0.061220799289344076]
# # 15 	Пример:  Baseball player in mid air swinging a tennis ball in his court .                                      	Оценка:  [0.45014617508912413, 0.2823719413662334, 0.10727633416507679, 0.06075459680224768]
# # 16 	Пример:  Two small children officers on a table holding Wii controllers .                                      	Оценка:  [0.3441236008058426, 0.2360815978543417, 0.09379601158083607, 0.05456617364591407]
# # 17 	Пример:  A girl embracing near a large glass computer screen window with a couch and luggage .                 	Оценка:  [0.5960395606792698, 0.4289887330498402, 0.2610490903329069, 0.12375243436757331]
# # 18 	Пример:  Some laptops are sitting in a pot couch park near two other people .                                  	Оценка:  [0.5428967140306369, 0.43422081861268574, 0.2634333477440361, 0.12465583273147404]
# # 19 	Пример:  A skateboarder sailing on the grass in front of some flowers .                                        	Оценка:  [0.45014617508912413, 0.38323768603830394, 0.3392375549949802, 0.3013029570566287]
# # 20 	Пример:  A box sitting up on top of a stove with a phone .                                                     	Оценка:  [0.6407232755171874, 0.5153155514398451, 0.3562051591376267, 0.2514989450772464]
# # 21 	Пример:  A kitchen with a ceiling couch reading in front of a window .                                         	Оценка:  [0.5231483637805969, 0.45016959891266206, 0.3827673535697134, 0.30600598041750904]
# # 22 	Пример:  Two men looking over a window - wrapped by their plates .                                             	Оценка:  [0.435285750066007, 0.2761227119166927, 0.10549074689987335, 0.059944245366591306]
# # 23 	Пример:  A TV sitting on top of a table which being held by Christmas .                                        	Оценка:  [0.6069769786668839, 0.5470839496727063, 0.44304031555249035, 0.3730395276999435]
# # 24 	Пример:  Several zebras standing next to each other on a area .                                                	Оценка:  [0.45014617508912413, 0.38323768603830394, 0.3392375549949802, 0.3013029570566287]
# # 25 	Пример:  A view of a grey horse viewing a small round filled lamp .                                            	Оценка:  [0.435285750066007, 0.2761227119166927, 0.18759202316167214, 0.09500522640872923]
# # 26 	Пример:  Man wearing tiny black and tie and a suit preparing a cake .                                          	Оценка:  [0.5231483637805969, 0.24773787754561394, 0.09724831363662378, 0.05616705675147311]
# # 27 	Пример:  A man wearing a hat is holding a kite on the walls .                                                  	Оценка:  [0.6407232755171874, 0.5424863881931092, 0.4402449689810936, 0.18798860484865026]
# # 28 	Пример:  A person sits on bed near a marble dining room .                                                      	Оценка:  [0.45014617508912413, 0.32323518297936166, 0.2111187176080899, 0.10442329545559932]
# # 29 	Пример:  A bunch of people sitting in the snow atop a room about to have and trees in her hands .              	Оценка:  [0.9176629354822471, 0.7206559132496348, 0.45807989852270203, 0.19405685606141923]
# # 30 	Пример:  There are a girl on a bed in front of people on a table at a child .                                  	Оценка:  [0.870571500132014, 0.7495123535686309, 0.47176896213068414, 0.1986824448717125]
# # 31 	Пример:  A woman sitting on a tree in the middle of a city holding lit umbrella .                              	Оценка:  [0.7108186533109109, 0.6547593501560818, 0.5610310064032589, 0.4505985040938768]
# # 32 	Пример:  A group of people sitting around a table with a doughnut .                                            	Оценка:  [0.5619514869490163, 0.5196828406118894, 0.4507482544534971, 0.37822261873373586]
# # 33 	Пример:  A closeup of a picture of a next to a desk .                                                          	Оценка:  [0.5619514869490163, 0.49705875547910827, 0.38368416816913054, 0.26690401508436334]
# # 34 	Пример:  A small child is using his racquet on a bench .                                                       	Оценка:  [0.45014617508912413, 0.3557663528269982, 0.2697856975860103, 0.12705481883633096]
# # 35 	Пример:  A man in a middle board is in his hands .                                                             	Оценка:  [0.45014617508912413, 0.3557663528269982, 0.2697856975860103, 0.12705481883633096]
# # 36 	Пример:  A building is next to many other produce at a cutting board .                                         	Оценка:  [0.5848976518656018, 0.42362581168373686, 0.2585976536992378, 0.1228218593141609]
# # 37 	Пример:  A person surfs a jump on the beach on the beach .                                                     	Оценка:  [0.39735970711951313, 0.2598414203059447, 0.17923344640485428, 0.09160332714436914]
# # 38 	Пример:  The meal consists a pepperoni sandwich sitting next to a building .                                   	Оценка:  [0.39735970711951313, 0.3273796750780409, 0.28051550320162943, 0.20775022276339775]
# # 39 	Пример:  A dog in his mouth playing a video case and staring at the camera to eat .                            	Оценка:  [0.7015021476502369, 0.434479129690036, 0.1482055473163841, 0.07868058333455581]
# # 40 	Пример:  The front of clad red building holds onto the reflection of a fireplace .                             	Оценка:  [0.4893604849295929, 0.34174500988297, 0.12378396963260613, 0.06812515889872198]
# # 41 	Пример:  A train station on a narrow track , driving the stairs and surrounded i it .                          	Оценка:  [0.6282808624375432, 0.4443225786734753, 0.15071676257541072, 0.07974532804532973]
# # 42 	Пример:  A bird is sitting in the bathroom with standing with a rock wall .                                    	Оценка:  [0.6649099662043687, 0.5560541333192193, 0.37712304653125106, 0.1660972577424094]
# # 43 	Пример:  A group of men standing around a surf board in the snow .                                             	Оценка:  [0.6407232755171874, 0.6109741448719966, 0.5326509505811611, 0.4322693266166363]
# # 44 	Пример:  A dog sitting on the desk near a dresser that is smiling .                                            	Оценка:  [0.6134458325505882, 0.5005841126806674, 0.3857233055230012, 0.26803820899643993]
# # 45 	Пример:  A stop sign on a wall next to two brown dogs .                                                        	Оценка:  [0.533113989983183, 0.4799049519403644, 0.3376849396274619, 0.2409824176325028]
# # 46 	Пример:  A group of people playing on the sand , the ocean country for the during sunset .                     	Оценка:  [0.7015021476502369, 0.47820615913318404, 0.28320384389628483, 0.13208555288986817]
# # 47 	Пример:  A man sitting on top of a laptop computer next to one foot is sitting on computer .                   	Оценка:  [0.8191780219091253, 0.7429488611029866, 0.6410345990025075, 0.55523288563439]
# # 48 	Пример:  A cookie and fish ready to a plate of carrots .                                                       	Оценка:  [0.41675437673324534, 0.21289360263974305, 0.08679800196561344, 0.05128422370728747]
# # 49 	Пример:  A white bird perched on a few furniture looking at a game .                                           	Оценка:  [0.5848976518656018, 0.48493050014758926, 0.3766410991613996, 0.26297724440774917]

# %% [markdown]
# Оценка качества генерации на основе SeqGAN

# %%
# %%time
print("Оценка качества генерации текстов на основе BLEU, после обучения с помощью SeqGAN")
degree = 1
print("Degree:", degree)
# проверка качества обучения
BLEU(data_file_test.tolist(), gen.sample(500, degree=degree).cpu().detach().numpy().tolist(), print_iteration=100)
# Out:
# Оценка качества генерации текстов на основе BLEU, после обучения с помощью SeqGAN
# Degree: 1
# --- --- ---
# Start BLEU
# 2 100 0.5074841333882112
# 2 200 0.514819199850076
# 2 300 0.5170806356845506
# 2 400 0.5191300973781708
# 2 500 0.5220390101251234
# --- --- ---
# 2 -gram BLEU score :  0.5220390101251234
#
# 3 100 0.38127956558435677
# 3 200 0.38821018244951083
# 3 300 0.38787361175157303
# 3 400 0.3886326887782336
# 3 500 0.3928964532399967
# --- --- ---
# 3 -gram BLEU score :  0.3928964532399967
#
# 4 100 0.2495628351282375
# 4 200 0.2609661607096216
# 4 300 0.260242412511415
# 4 400 0.26050172139711614
# 4 500 0.26614798307671744
# --- --- ---
# 4 -gram BLEU score :  0.26614798307671744
#
# 5 100 0.15493427465216825
# 5 200 0.16303737643799224
# 5 300 0.16267665562072717
# 5 400 0.16399300449864895
# 5 500 0.17012601345146197
# --- --- ---
# 5 -gram BLEU score :  0.17012601345146197
#
# CPU times: user 7min 52s, sys: 176 ms, total: 7min 53s
# Wall time: 7min 52s

# %% [markdown]
# Оценка с возведением в степень

# %%
# примеры сгенерированных текстов
print("Примеры генерируемых текстов на основе SeqGAN с возведением в степень")
degree = 1.5
print("Degree:", degree)
samples = gen.sample(50, degree=degree).cpu().detach().numpy()

output_function = []
for i, samp in enumerate(samples):
  line = [word[x] for x in samp]
  line = ' '.join(line)
  output_function.append(line)
  bleu = BLEU(data_file_test.tolist(), [samp], flag_print=False)
  print("#", i, "\tПример: ", line, ' '*(100-len(line)), '\tОценка: ', bleu)
# Out:
# Примеры генерируемых текстов на основе SeqGAN с возведением в степень
# Degree: 1.5
# # 0 	Пример:  A man standing in a room with a table in front of a building .                                        	Оценка:  [0.7433919416750281, 0.716882776507279, 0.6452772832060505, 0.5581707898352563]
# # 1 	Пример:  A person in a room with a white laptop computer .                                                     	Оценка:  [0.5104177855340404, 0.46618580376022084, 0.39293620890698494, 0.2720405498897358]
# # 2 	Пример:  A man on a table with a man standing on the ground .                                                  	Оценка:  [0.6407232755171874, 0.6306964608093198, 0.5454951299940093, 0.35367853716020087]
# # 3 	Пример:  A person standing on top of a small grass field .                                                     	Оценка:  [0.5104177855340404, 0.46618580376022084, 0.3656683453259979, 0.2568300857166973]
# # 4 	Пример:  A couple of men standing in front of a table with a laptop .                                          	Оценка:  [0.6920602346769048, 0.6834900197659399, 0.6226004058995851, 0.5424222850535521]
# # 5 	Пример:  A man in a park playing with a kite .                                                                 	Оценка:  [0.4588314677411235, 0.3881515247704053, 0.2421802605288374, 0.11654321569849413]
# # 6 	Пример:  A man is standing next to a boat near some for a layered cake .                                       	Оценка:  [0.6366028258614133, 0.5401580917794444, 0.43882709237469125, 0.29717395847795103]
# # 7 	Пример:  A woman lies with a couch in front of a TV .                                                          	Оценка:  [0.533113989983183, 0.42898873304984025, 0.3435599238920265, 0.2806622489471059]
# # 8 	Пример:  A man in a room with a couch , television , chairs , tables and chair .                               	Оценка:  [0.7914011558455574, 0.6790802839709907, 0.5508978937456941, 0.44407583794173916]
# # 9 	Пример:  A young boy is standing in front of a TV .                                                            	Оценка:  [0.5380275868489703, 0.5250407733778476, 0.4940911248125205, 0.45083294673070695]
# # 10 	Пример:  A group of people on a zebra standing in front of a brick building .                                  	Оценка:  [0.7433919416750281, 0.6746125211776158, 0.6165255292124369, 0.5381840915123799]
# # 11 	Пример:  A man sitting on a couch , with a tennis racket .                                                     	Оценка:  [0.5104177855340404, 0.44283653888216973, 0.37808143557096185, 0.3286007399510472]
# # 12 	Пример:  A man with a helmet and tie and a knife .                                                             	Оценка:  [0.5104177855340404, 0.44283653888216973, 0.35184442107863445, 0.28606355926390736]
# # 13 	Пример:  A man smiles as he leaps in the air over a ski slope .                                                	Оценка:  [0.5848976518656018, 0.45633707214217845, 0.2734337278147286, 0.12842739402168749]
# # 14 	Пример:  A man is sitting on the beach while holding a small dog .                                             	Оценка:  [0.6134458325505882, 0.5730257633814818, 0.48502137897242614, 0.36982026735732837]
# # 15 	Пример:  A person standing in a living room holding a game controller .                                        	Оценка:  [0.5026246899500345, 0.41247254393856775, 0.3584668928097086, 0.2527756550992427]
# # 16 	Пример:  A man standing in a room with a couch with a dog .                                                    	Оценка:  [0.6407232755171874, 0.6306964608093198, 0.5861726646477367, 0.4943203061900201]
# # 17 	Пример:  A young girl sitting on a sofa with a boy in the background .                                         	Оценка:  [0.6366028258614133, 0.48284922775266165, 0.33923755499498015, 0.1526086473594013]
# # 18 	Пример:  A young girl sitting at a table looking on the side of a street .                                     	Оценка:  [0.716350399411379, 0.6109741448719966, 0.5089175114935747, 0.41679084443402403]
# # 19 	Пример:  A man standing in front of a piece of cake .                                                          	Оценка:  [0.5380275868489703, 0.5048265531987134, 0.46161745771674506, 0.4083323438828161]
# # 20 	Пример:  A white and white cat resting on the floor .                                                          	Оценка:  [0.4866642633922876, 0.42898873304984025, 0.2610490903329069, 0.12375243436757331]
# # 21 	Пример:  Two women sitting on a couch next to a wooden table .                                                 	Оценка:  [0.5893796917545019, 0.5131038694945721, 0.39293620890698494, 0.17164598294935923]
# # 22 	Пример:  A man with a beard and a hot dog in the middle of a bathroom .                                        	Оценка:  [0.7947194142390263, 0.7280858794306144, 0.6075227400262042, 0.508672234420547]
# # 23 	Пример:  A man looks out a window while a man in his underwear .                                               	Оценка:  [0.6134458325505882, 0.43730050179518515, 0.14892676349028391, 0.07898674271716548]
# # 24 	Пример:  A man with a toothbrush in front of a statue .                                                        	Оценка:  [0.5380275868489703, 0.48284922775266165, 0.33923755499498015, 0.1526086473594013]
# # 25 	Пример:  A woman sitting on a couch with a large pizza .                                                       	Оценка:  [0.5104177855340404, 0.46618580376022084, 0.4154794556635241, 0.3753424158030879]
# # 26 	Пример:  A group of people standing on a beach with a kite .                                                   	Оценка:  [0.5893796917545019, 0.5579390770002352, 0.4496171332314307, 0.3774631294325764]
# # 27 	Пример:  A woman is holding a Nintendo Wii controller in the bed .                                             	Оценка:  [0.42919753763947605, 0.3131273945313386, 0.1159253906061508, 0.06464260622956182]
# # 28 	Пример:  A man is sitting at a table with fresh bottles of wine .                                              	Оценка:  [0.5848976518656018, 0.5337350774191416, 0.48130446616982553, 0.4222055277665569]
# # 29 	Пример:  A man sitting on a couch playing a video game .                                                       	Оценка:  [0.4812265031857878, 0.37195938466682343, 0.3087021994559367, 0.25764029136167466]
# # 30 	Пример:  A man about to hit a tennis ball in a field .                                                         	Оценка:  [0.533113989983183, 0.3982378626139663, 0.293597382795084, 0.21546550289591512]
# # 31 	Пример:  A young girl is sitting on a laptop computer on a desk .                                              	Оценка:  [0.6407232755171874, 0.6306964608093198, 0.566927566896732, 0.3647523205532165]
# # 32 	Пример:  A woman and a girl in a baseball uniform holding a bat .                                              	Оценка:  [0.6407232755171874, 0.6306964608093198, 0.566927566896732, 0.4812935724427397]
# # 33 	Пример:  A woman sitting at a table with a bowl of cake .                                                      	Оценка:  [0.5893796917545019, 0.5579390770002352, 0.5171331332905545, 0.4471671515841253]
# # 34 	Пример:  A cat is standing on top of a bed with a frisbee .                                                    	Оценка:  [0.6407232755171874, 0.6306964608093198, 0.5454951299940093, 0.44058829641841857]
# # 35 	Пример:  A man standing in a lake with a large umbrella .                                                      	Оценка:  [0.5380275868489703, 0.5250407733778476, 0.4542291944311804, 0.3509150848958905]
# # 36 	Пример:  A young girl standing on a wooden bench with a tennis racket .                                        	Оценка:  [0.5619514869490163, 0.49705875547910827, 0.412295470431275, 0.3247497709709059]
# # 37 	Пример:  A man standing on a small white park bench with a surfboard .                                         	Оценка:  [0.6134458325505882, 0.5730257633814818, 0.45870489935032144, 0.30789504975056203]
# # 38 	Пример:  A man that is sitting on top of a wooden bench .                                                      	Оценка:  [0.5893796917545019, 0.5778821454656745, 0.5653636138834072, 0.5516406790211416]
# # 39 	Пример:  A dog laying on the bed in front of a television .                                                    	Оценка:  [0.5893796917545019, 0.5131038694945721, 0.4464617303464354, 0.37534241580308786]
# # 40 	Пример:  A man is a kite in the air in the middle of the air .                                                 	Оценка:  [0.716350399411379, 0.6354387175256053, 0.4956875628161808, 0.376312305781749]
# # 41 	Пример:  A person flying a kite walking down a road with cloudy sky .                                          	Оценка:  [0.5848976518656018, 0.45633707214217845, 0.2734337278147286, 0.12842739402168749]
# # 42 	Пример:  A group of people standing on a beach with a skateboard .                                             	Оценка:  [0.5893796917545019, 0.5778821454656745, 0.46161745771674506, 0.3855014663175419]
# # 43 	Пример:  A woman standing on a plate on a street next to a cat .                                               	Оценка:  [0.6920602346769048, 0.6834900197659399, 0.6226004058995851, 0.4515954131875879]
# # 44 	Пример:  A man standing in front of a couch , dining room table .                                              	Оценка:  [0.6134458325505882, 0.5269782107608059, 0.4307717965077675, 0.3647523205532165]
# # 45 	Пример:  A man holding a checkered phone while sitting in front of a shelf .                                   	Оценка:  [0.6649099662043687, 0.5813634471819698, 0.46370156242460314, 0.3105752552742679]
# # 46 	Пример:  A vintage photo of a man in a room with a TV .                                                        	Оценка:  [0.6407232755171874, 0.6306964608093198, 0.566927566896732, 0.4812935724427397]
# # 47 	Пример:  A plate of pizza on a plate with a fork .                                                             	Оценка:  [0.4866642633922876, 0.42898873304984025, 0.36917916399395617, 0.32239626367530877]
# # 48 	Пример:  A man in a beanie and on a table with a book .                                                        	Оценка:  [0.6407232755171874, 0.6109741448719966, 0.5326509505811611, 0.4322693266166363]
# # 49 	Пример:  A snowboarder snowboarding in the air during a day .                                                  	Оценка:  [0.3077935056255462, 0.17394640854894952, 0.0745932224853342, 0.04542924288455331]

# %%
# %%time
print("Оценка качества генерации текстов на основе BLEU, после обучения с помощью SeqGAN")
# проверка качества обучения
BLEU(data_file_test.tolist(), gen.sample(500, degree=degree).cpu().detach().numpy().tolist(), print_iteration=100)
# Out:
# Оценка качества генерации текстов на основе BLEU, после обучения с помощью SeqGAN
# --- --- ---
# Start BLEU
# 2 100 0.5746959166408108
# 2 200 0.5712008863573584
# 2 300 0.567327534197651
# 2 400 0.569402426596509
# 2 500 0.5716843921414854
# --- --- ---
# 2 -gram BLEU score :  0.5716843921414854
#
# 3 100 0.5050846828032072
# 3 200 0.49620438762803126
# 3 300 0.49256672478599955
# 3 400 0.4990660653296927
# 3 500 0.5028216465603539
# --- --- ---
# 3 -gram BLEU score :  0.5028216465603539
#
# 4 100 0.4125649208522431
# 4 200 0.4031958117320594
# 4 300 0.4005020051371067
# 4 400 0.4098193662865048
# 5 100 0.30949307637919304
# 5 200 0.2988029014742637
# 5 300 0.2952895890220848
# 5 400 0.3042843311354224
# 5 500 0.3068178815954311
# --- --- ---
# 5 -gram BLEU score :  0.3068178815954311
#
# CPU times: user 7min 41s, sys: 165 ms, total: 7min 42s
# Wall time: 7min 41s

# %% [markdown]
# Загрузка сохраненной модели

# %%
# загрузка моделей
[data_file_tensor_train, gen, dis, gen_optimizer, dis_optimizer,
VOCAB_SIZE, MAX_SEQ_LEN, GEN_EMBEDDING_DIM, GEN_HIDDEN_DIM, DIS_EMBEDDING_DIM,
 DIS_HIDDEN_DIM] = load_models(FILE_PATHS['saved_models'] + r'/' + r'seqgan_adversarial_training.pytorch')#[seqgan_mle, seqgan_pretraining_dis, seqgan_adversarial_training]

if(CUDA):
  gen = gen.cuda()
  dis = dis.cuda()
  data_file_tensor_train = torch.tensor(data_file_tensor_train).cuda()
  data_file_tensor_test = torch.tensor(data_file_test).cuda()
# Out:
# state
# default_parameters
# data_file_tensor_train
# Generator
# Discriminator
# CUDA
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   if __name__ == '__main__':

# %% [markdown]
# Оценка разнообразия текста

# %%
degree = 1.5

# %%
# плагиат из обучающей выборки
samples = gen.sample(1500, degree=degree).cpu().detach().numpy().tolist()
# samples = data_file_test.tolist()[:500]
train_samples = data_file_train.tolist()
n = 0
for i in range(len(samples)):
  if samples[i] in train_samples:
    n += 1
  if i%(len(samples)//10) == 0:
    print(i/len(samples)*100, "%")
print("Совпало сгенерированных примеров с обучающей выборкой: ", n, "из", len(samples))
print("Плагиат: ", n/len(samples)*100, "%")
# Out:
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Совпало сгенерированных примеров с обучающей выборкой:  9 из 1500
# Плагиат:  0.6 %

# %%
# оригинальность примеров
N_samples = 1500
samples_1 = gen.sample(N_samples, degree=degree).cpu().detach().numpy().tolist()
samples_2 = gen.sample(N_samples, degree=degree).cpu().detach().numpy().tolist()

n = 0
for i in range(len(samples_1)):
  if samples_1[i] in samples_2:
    n += 1
  if i%(len(samples_1)//10) == 0:
    print(i/len(samples_1)*100, "%")

print("Оригинальность генерируемых примеров")
print("Совпало примеров из выборки 1 с примерами из выборки 2: ", n, "из", len(samples_1))
print("Плагиат: ", n/len(samples_1)*100, "%")
print("Оригинальность: ", (1-n/len(samples_1))*100, "%")
# Out:
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Оригинальность генерируемых примеров
# Совпало примеров из выборки 1 с примерами из выборки 2:  22 из 1500
# Плагиат:  1.4666666666666666 %
# Оригинальность:  98.53333333333333 %

# %%
# оригинальность примеров подход 2
N_samples = 1500
samples = gen.sample(N_samples, degree=degree).cpu().detach().numpy().tolist()

i = 0
n = 0
while len(samples)>0:
  if samples[0] not in samples[1:]:
    n += 1
  if i%(N_samples//10) == 0:
    print(i/N_samples*100, "%")
  del(samples[0])
  i += 1

print("Оригинальность генерируемых примеров")
print("Сгенерировано оригинальных примеров: ", n, "из", N_samples)
print("Оригинальность: ", n/N_samples*100, "%")
print("Плагиат: ", (1-n/N_samples)*100, "%")
# Out:
# 0.0 %
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# Оригинальность генерируемых примеров
# Сгенерировано оригинальных примеров:  1493 из 1500
# Оригинальность:  99.53333333333333 %
# Плагиат:  0.4666666666666708 %
